# %% [markdown]
# # Importation

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("/content/ensai2023_mode_responsable.json")

# %%
df.head()
# Out:
#    total                                            results  seed
# 0   2996  {'id': '5a7a6889-5d25-4511-b707-c5a66c9837f5',...   NaN
# 1   2996  {'id': 'edb4dc7a-6bca-4968-864d-94d2fbe5dd7c',...   NaN
# 2   2996  {'id': 'a1a5c25c-cd1e-4320-8d9a-b1dc6a81062d',...   NaN
# 3   2996  {'id': '45c55e25-c096-423b-8ed1-ddc9d647eb29',...   NaN
# 4   2996  {'id': '63dbc10a-c0c3-4750-831a-ffdac26563b5',...   NaN

# %%
import json

with open('/content/ensai2023_mode_responsable.json') as mon_fichier:
    data = json.load(mon_fichier)

# %%
from pandas import json_normalize
df = json_normalize(data['results']) #Results contain the required data
df.head()
# Out:
#                                      id                                userId  \
# 0  5a7a6889-5d25-4511-b707-c5a66c9837f5  b8c60904-a528-4bd5-9df2-1acd4bb08198
# 1  edb4dc7a-6bca-4968-864d-94d2fbe5dd7c  613bf30c-41da-4824-8986-72d6d8a3dcdc
# 2  a1a5c25c-cd1e-4320-8d9a-b1dc6a81062d  2789ee1f-ae69-4390-ab88-3c8c1271cec3
# 3  45c55e25-c096-423b-8ed1-ddc9d647eb29  255c62b7-9cdf-4bb1-84ee-c377c8e5aaa2
# 4  63dbc10a-c0c3-4750-831a-ffdac26563b5  01a424c4-9428-4d01-aa60-921ce8af0c0e
#
#                                              content  \
# 0  il faut encourager les marques à sélectionner ...
# 1  Il faut éviter de fabriquer pour les enfants d...
# 2  Il faut de la prévention sur les risques pour ...
# 3  Il faut ne faut pas acheter trop de vêtements ...
# 4  Il faut cesser de promouvoir des modes très ch...
#
#                                                 slug    status  \
# 0  il-faut-encourager-les-marques-a-selectionner-...  Accepted
# 1  il-faut-eviter-de-fabriquer-pour-les-enfants-d...  Accepted
# 2  il-faut-de-la-prevention-sur-les-risques-pour-...  Accepted
# 3  il-faut-ne-faut-pas-acheter-trop-de-vetements-...  Accepted
# 4  il-faut-cesser-de-promouvoir-des-modes-tres-ch...  Accepted
#
#                   createdAt                 updatedAt  \
# 0  2020-09-29T06:56:06.843Z  2020-10-22T09:03:34.552Z
# 1  2020-09-10T08:20:14.963Z  2020-09-15T14:37:07.808Z
# 2  2020-10-05T22:29:35.735Z  2020-10-15T10:20:43.198Z
# 3  2020-09-09T16:50:22.508Z  2020-09-28T10:26:14.911Z
# 4  2020-09-03T19:07:10.784Z  2020-09-28T10:26:13.407Z
#
#                                                votes trending labels  ...  \
# 0  [{'voteKey': 'agree', 'count': 466, 'qualifica...  popular     []  ...
# 1  [{'voteKey': 'agree', 'count': 7, 'qualificati...     None     []  ...
# 2  [{'voteKey': 'agree', 'count': 234, 'qualifica...  popular     []  ...
# 3  [{'voteKey': 'agree', 'count': 29, 'qualificat...     None     []  ...
# 4  [{'voteKey': 'agree', 'count': 269, 'qualifica...  popular     []  ...
#
#       question.slug question.wording.title  \
# 0  mode-responsable       Mode Responsable
# 1  mode-responsable       Mode Responsable
# 2  mode-responsable       Mode Responsable
# 3  mode-responsable       Mode Responsable
# 4  mode-responsable       Mode Responsable
#
#                            question.wording.question  question.countries  \
# 0  Comment agir ensemble pour une mode plus respo...                [FR]
# 1  Comment agir ensemble pour une mode plus respo...                [FR]
# 2  Comment agir ensemble pour une mode plus respo...                [FR]
# 3  Comment agir ensemble pour une mode plus respo...                [FR]
# 4  Comment agir ensemble pour une mode plus respo...                [FR]
#
#   question.language        question.startDate          question.endDate  \
# 0                fr  2020-09-03T07:00:00.000Z  2020-10-25T17:00:00.000Z
# 1                fr  2020-09-03T07:00:00.000Z  2020-10-25T17:00:00.000Z
# 2                fr  2020-09-03T07:00:00.000Z  2020-10-25T17:00:00.000Z
# 3                fr  2020-09-03T07:00:00.000Z  2020-10-25T17:00:00.000Z
# 4                fr  2020-09-03T07:00:00.000Z  2020-10-25T17:00:00.000Z
#
#                  selectedStakeTag.tagId               selectedStakeTag.label  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2  055f61f1-c4ef-43fe-bf1c-98cd8630a901  Matières et procédés de fabrication
# 3  26b0b87e-e85a-422a-bb7f-3bba54c25d13  Durée de vie des produits (qualité)
# 4  26b0b87e-e85a-422a-bb7f-3bba54c25d13  Durée de vie des produits (qualité)
#
#   selectedStakeTag.display
# 0                      NaN
# 1                      NaN
# 2                     True
# 3                     True
# 4                     True
#
# [5 rows x 43 columns]

# %%
df.columns
# Out:
# Index(['id', 'userId', 'content', 'slug', 'status', 'createdAt', 'updatedAt',
#        'votes', 'trending', 'labels', 'organisations', 'tags',
#        'selectedStakeTag', 'myProposal', 'idea', 'operationId', 'proposalKey',
#        'context.operation', 'context.source', 'context.location',
#        'context.question', 'context.country', 'context.language',
#        'context.getParameters', 'author.firstName', 'author.displayName',
#        'author.organisationName', 'author.organisationSlug',
#        'author.postalCode', 'author.age', 'author.avatarUrl',
#        'author.userType', 'question.questionId', 'question.slug',
#        'question.wording.title', 'question.wording.question',
#        'question.countries', 'question.language', 'question.startDate',
#        'question.endDate', 'selectedStakeTag.tagId', 'selectedStakeTag.label',
#        'selectedStakeTag.display'],
#       dtype='object')

# %%
df.trending
# Out:
# 0       popular
# 1          None
# 2       popular
# 3          None
# 4       popular
#          ...
# 2991    popular
# 2992       None
# 2993    popular
# 2994    popular
# 2995       None
# Name: trending, Length: 2996, dtype: object

# %%
target_columns = ["content", "votes", "author.age", "author.postalCode"]

# %%
df_target = df[target_columns]
df_target.head()
# Out:
#                                              content  \
# 0  il faut encourager les marques à sélectionner ...
# 1  Il faut éviter de fabriquer pour les enfants d...
# 2  Il faut de la prévention sur les risques pour ...
# 3  Il faut ne faut pas acheter trop de vêtements ...
# 4  Il faut cesser de promouvoir des modes très ch...
#
#                                                votes  author.age  \
# 0  [{'voteKey': 'agree', 'count': 466, 'qualifica...        37.0
# 1  [{'voteKey': 'agree', 'count': 7, 'qualificati...        46.0
# 2  [{'voteKey': 'agree', 'count': 234, 'qualifica...         NaN
# 3  [{'voteKey': 'agree', 'count': 29, 'qualificat...         NaN
# 4  [{'voteKey': 'agree', 'count': 269, 'qualifica...        29.0
#
#   author.postalCode
# 0             75020
# 1             75012
# 2              None
# 3             35600
# 4              None

# %%
votes = json_normalize(df['votes'])

# %%
votes = df['votes'].apply(pd.Series)

# %%
sous_votes_agree = votes.iloc[:, 0].apply(pd.Series)
sous_votes_disagree = votes.iloc[:, 1].apply(pd.Series)
sous_votes_neutral = votes.iloc[:, 2].apply(pd.Series)

# %%
agree_count = list(sous_votes_agree["count"])
disagree_count = list(sous_votes_disagree["count"])
neutral_count = list(sous_votes_neutral["count"])

# %%
agree_qualifications = sous_votes_agree['qualifications'].apply(pd.Series)

# %%
agree_likeIt = agree_qualifications.iloc[:,0].apply(pd.Series)
agree_doable = agree_qualifications.iloc[:,1].apply(pd.Series)
agree_platitude = agree_qualifications.iloc[:,2].apply(pd.Series)

# %%
agree_count_likeIt = list(agree_likeIt["count"])
agree_count_doable = list(agree_doable["count"])
agree_count_platitude = list(agree_platitude["count"])

# %%
disagree_qualifications = sous_votes_neutral['qualifications'].apply(pd.Series)
print(disagree_qualifications)
# Out:
#                                                       0  \
# 0     {'qualificationKey': 'doNotUnderstand', 'count...
# 1     {'qualificationKey': 'doNotUnderstand', 'count...
# 2     {'qualificationKey': 'doNotUnderstand', 'count...
# 3     {'qualificationKey': 'doNotUnderstand', 'count...
# 4     {'qualificationKey': 'doNotUnderstand', 'count...
# ...                                                 ...
# 2991  {'qualificationKey': 'doNotUnderstand', 'count...
# 2992  {'qualificationKey': 'doNotUnderstand', 'count...
# 2993  {'qualificationKey': 'doNotUnderstand', 'count...
# 2994  {'qualificationKey': 'doNotUnderstand', 'count...
# 2995  {'qualificationKey': 'doNotUnderstand', 'count...
#
#                                                       1  \
# 0     {'qualificationKey': 'noOpinion', 'count': 6, ...
# 1     {'qualificationKey': 'noOpinion', 'count': 0, ...
# 2     {'qualificationKey': 'noOpinion', 'count': 9, ...
# 3     {'qualificationKey': 'noOpinion', 'count': 2, ...
# 4     {'qualificationKey': 'noOpinion', 'count': 8, ...
# ...                                                 ...
# 2991  {'qualificationKey': 'noOpinion', 'count': 0, ...
# 2992  {'qualificationKey': 'noOpinion', 'count': 3, ...
# 2993  {'qualificationKey': 'noOpinion', 'count': 2, ...
# 2994  {'qualificationKey': 'noOpinion', 'count': 3, ...
# 2995  {'qualificationKey': 'noOpinion', 'count': 2, ...
#
#                                                       2
# 0     {'qualificationKey': 'doNotCare', 'count': 8, ...
# 1     {'qualificationKey': 'doNotCare', 'count': 0, ...
# 2     {'qualificationKey': 'doNotCare', 'count': 4, ...
# 3     {'qualificationKey': 'doNotCare', 'count': 2, ...
# 4     {'qualificationKey': 'doNotCare', 'count': 9, ...
# ...                                                 ...
# 2991  {'qualificationKey': 'doNotCare', 'count': 1, ...
# 2992  {'qualificationKey': 'doNotCare', 'count': 0, ...
# 2993  {'qualificationKey': 'doNotCare', 'count': 1, ...
# 2994  {'qualificationKey': 'doNotCare', 'count': 0, ...
# 2995  {'qualificationKey': 'doNotCare', 'count': 5, ...
#
# [2996 rows x 3 columns]

# %%
disagree_qualifications = sous_votes_disagree['qualifications'].apply(pd.Series)

disagree_noWay = disagree_qualifications.iloc[:,0].apply(pd.Series)
disagree_impossible = disagree_qualifications.iloc[:,1].apply(pd.Series)
disagree_platitude = disagree_qualifications.iloc[:,2].apply(pd.Series)

disagree_count_noWay = list(disagree_noWay["count"])
disagree_count_impossible = list(disagree_impossible["count"])
disagree_count_platitude = list(disagree_platitude["count"])


neutral_qualifications = sous_votes_neutral['qualifications'].apply(pd.Series)

neutral_doNotUnderstand = neutral_qualifications.iloc[:,0].apply(pd.Series)
neutral_noOpinion = neutral_qualifications.iloc[:,1].apply(pd.Series)
neutral_doNotCare = neutral_qualifications.iloc[:,2].apply(pd.Series)

neutral_count_doNotUnderstand = list(neutral_doNotUnderstand["count"])
neutral_count_noOpinion = list(neutral_noOpinion["count"])
neutral_count_doNotCare = list(neutral_doNotCare["count"])

# %%
df_wqual = df_target.assign(agree = agree_count, agree_count_likeIt = agree_count_likeIt, agree_count_doable= agree_count_doable,agree_count_platitude =agree_count_platitude , disagree = disagree_count, disagree_noWay = disagree_count_noWay, disagree_impossible = disagree_count_impossible, disagree_platitude =disagree_count_platitude, neutral = neutral_count, neutral_doNotUnderstand= neutral_count_doNotUnderstand, neutral_noOpinion = neutral_count_noOpinion, neutral_count_doNotCare= neutral_count_doNotCare )

# %%
df_wqual.head()
# Out:
#                                              content  \
# 0  il faut encourager les marques à sélectionner ...
# 1  Il faut éviter de fabriquer pour les enfants d...
# 2  Il faut de la prévention sur les risques pour ...
# 3  Il faut ne faut pas acheter trop de vêtements ...
# 4  Il faut cesser de promouvoir des modes très ch...
#
#                                                votes  author.age  \
# 0  [{'voteKey': 'agree', 'count': 466, 'qualifica...        37.0
# 1  [{'voteKey': 'agree', 'count': 7, 'qualificati...        46.0
# 2  [{'voteKey': 'agree', 'count': 234, 'qualifica...         NaN
# 3  [{'voteKey': 'agree', 'count': 29, 'qualificat...         NaN
# 4  [{'voteKey': 'agree', 'count': 269, 'qualifica...        29.0
#
#   author.postalCode  agree  agree_count_likeIt  agree_count_doable  \
# 0             75020    466                  95                 118
# 1             75012      7                   2                   1
# 2              None    234                  46                  70
# 3             35600     29                   8                   4
# 4              None    269                  63                  69
#
#    agree_count_platitude  disagree  disagree_noWay  disagree_impossible  \
# 0                     25         8               0                    3
# 1                      2         2               0                    0
# 2                     12         8               1                    2
# 3                      7         2               0                    0
# 4                     15        12               3                    3
#
#    disagree_platitude  neutral  neutral_doNotUnderstand  neutral_noOpinion  \
# 0                   3       28                        3                  6
# 1                   1        4                        0                  0
# 2                   1       28                        1                  9
# 3                   1        7                        1                  2
# 4                   1       42                        1                  8
#
#    neutral_count_doNotCare
# 0                        8
# 1                        0
# 2                        4
# 3                        2
# 4                        9

# %%
df_wqual = df_wqual.drop(votes)

# %%
df_wqual.to_csv("dw_wqual")

# %% [markdown]
# # Nettoyage

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)

# %%
pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.2)

# %%
# !python -m spacy download fr_core_news_md
# Out:
# 2023-06-16 06:49:22.790406: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-16 06:49:23.971528: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fr-core-news-md==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_md-3.5.0/fr_core_news_md-3.5.0-py3-none-any.whl (45.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 MB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from fr-core-news-md==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->fr-core-news-md==3.5.0) (2.1.2)
# Installing collected packages: fr-core-news-md
# Successfully installed fr-core-news-md-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_md')

# %%
# !pip install zeugma &> /dev/null

# %%
pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)

# %%
import numpy as np
import json
import spacy
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# %%
mots = set(line.strip() for line in open('/content/dictionnaire.txt'))

# %%
nlp = spacy.load('fr_core_news_md')

# %%
df = pd.read_csv('/content/dw_wqual')

# %%
df.head()
# Out:
#    Unnamed: 0                                            content  \
# 0           3  Il faut ne faut pas acheter trop de vêtements ...
# 1           4  Il faut cesser de promouvoir des modes très ch...
# 2           5  il faut supprimer la méthode de sablage pour v...
# 3           6  Il faut encourager les marques à produire en E...
# 4           7  Il faut lourdement taxer le transport par port...
#
#                                                votes  author.age  \
# 0  [{'voteKey': 'agree', 'count': 29, 'qualificat...         NaN
# 1  [{'voteKey': 'agree', 'count': 269, 'qualifica...        29.0
# 2  [{'voteKey': 'agree', 'count': 35, 'qualificat...        50.0
# 3  [{'voteKey': 'agree', 'count': 57, 'qualificat...        29.0
# 4  [{'voteKey': 'agree', 'count': 98, 'qualificat...        50.0
#
#    author.postalCode  agree  agree_count_likeIt  agree_count_doable  \
# 0            35600.0     29                   8                   4
# 1                NaN    269                  63                  69
# 2            66000.0     35                   3                   9
# 3            31300.0     57                  12                  12
# 4                NaN     98                  20                  22
#
#    agree_count_platitude  disagree  disagree_noWay  disagree_impossible  \
# 0                      7         2               0                    0
# 1                     15        12               3                    3
# 2                      4         3               1                    1
# 3                      4         1               0                    0
# 4                      2         9               2                    2
#
#    disagree_platitude  neutral  neutral_doNotUnderstand  neutral_noOpinion  \
# 0                   1        7                        1                  2
# 1                   1       42                        1                  8
# 2                   0       19                        3                  6
# 3                   1        3                        0                  1
# 4                   1       21                        1                  4
#
#    neutral_count_doNotCare
# 0                        2
# 1                        9
# 2                        2
# 3                        0
# 4                        0

# %%
import nltk
nltk.download('punkt')

sentence_list = []
lemma_list = []
lemma_sentences = []

for content in df['content']:
    doc = nlp(content)  # Traitement du texte avec spaCy
    lemma = []
    for token in doc:
        lemma.append(token.lemma_)
    lemma_list.append(lemma)
    sentence_list.append(doc.text)
    lemma_sentence = ' '.join(lemma)
    lemma_sentences.append(lemma_sentence)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
print(lemma_sentences)
# Out:
# ['il falloir ne falloir pas acheter trop de vêtement qui être peu ou pas utiliser et qui être de mauvais qualité', 'il falloir cesser de promouvoir un mode très changeant en son privilégier un vêtement durable , ce est - à - dire solide et de bon qualité', 'il falloir supprimer le méthode de sablage pour vieillir le vêtement', 'il falloir encourager le marque à produire en Europe , avec un matière durable et écoresponsable : naturel , bio ou recyclée .', 'il falloir lourdement taxer le transport par porte-container . pollution fort et travailleur quasi-esclave .', 'il falloir imposer aux marque le affichage , sur leur étiquette , de son notation par clearfashion', 'il falloir changer notre procédé de teinture pour un teinture moins polluant et moins énergivore .', 'il falloir faire de plus en plus de recyclage , utiliser un chute pour reconfectionner', 'il falloir arrêter d’ importer un produit de Chine . pays qui ne respecter ni l’ environnement , ni le droit de l’ homme .', 'il falloir aider le gens à ré-apprendre à coudre ( main sur machine ) pour son permettre de réparer / transformer / relooker leur vêtement .', 'il falloir mettre en place un vrai label certifiant que le produit respecter un condition de production écologique et humain', 'il falloir soutenir financièrement le création de structure de réparation de vêtement abîmer pour éviter que il finir à le déchetterie', 'il falloir interdire à marque de jeter un vêtement neuf', 'il falloir labelliser le entreprise qui être le moins polluant et le plus éthique ( avec un sticker sur le vitrine )', 'il falloir développer le second - hand shops , même au sein de magasin de vêtement neuf .', 'il falloir mieux afficher le provenance de vêtement et de le matière premier . aller jusqu’ à calculer l’ impact carbone de vêtement !', 'il falloir relocaliser production en Europe ou Maghreb , condition de travail respectueux , matière premier durable etc.', 'il falloir que le magasin / marque proposer un point de collecte de vêtement pour faire un don à association .', 'il falloir que de coton   bio et produire en france ou en europe afin de limiter le impact sur notre environnement', 'il falloir arrêter de produire un vêtement à bas coût , qu’ il falloir jeter après deux lavage', 'il falloir diminuer de manière drastique le pollution générer par le mode ( pesticide , teinture de textile ... )', 'il falloir créer un label qui permettre au consommateur de savoir ce qu’ il acheter', 'il falloir développer le upcycling de matière , y compris chez le marque qui vendre de grand quantité ( défi sur le process de production )', 'il falloir informer le citoyen sur le danger social , éthique et environnemental de le fast fashion', 'il falloir contraindre le règle de production , interdire à le vente le produit non-responsable', 'il falloir revaloriser le métier de textile et leur formation en France dans le souci de le préservation de le environnement , de l’ économie', 'il falloir supprimer le détergent chimique et toxique', 'il falloir encourager le échange de vêtement . retour au troc', 'il falloir rappeler aux client.e. de ne pas trop consommer .', 'il falloir produire le tissu et fabriquer le vêtement localement , ou à minimum dans le Pays européen voisin et sans substance dangereux .', 'il falloir un textile qui résister dans le temps et qui ne boulochent pas', 'il falloir que le enseigne proposer un service de location de vêtement pour bébé', 'il falloir continuer à encourager le upcycling et le communauté de échange .', 'il falloir que le mode ne être plus le premier critère dans le achat , mais que le critère être : en avoir je vraiment   besoin ?', 'il falloir produire le fibre , le tisser et confectionner / designer le vêtement en France ( à défaut en Europe )', 'il falloir privilégier le fibre naturel et éliminer le fibre synthétique', 'il falloir établir un relation constructif , éthique et éco-responsable avec son fournisseur .', 'il falloir fabriquer un tissu en matière le plu ...

# %%
from spacy.lang.fr.stop_words import STOP_WORDS
stop = STOP_WORDS
print(stop)
stop_perso = ['falloir', '’']
# Out:
# {'sept', 'moi-meme', 'vingt', 'pourrait', "d'", 'ha', 'ayant', 'qu’', 'cet', 'siennes', 's’', 'ceux', 'duquel', 'avant', 'en', 'houp', 'quatrièmement', 'reste', 'cependant', 'environ', 'combien', 'certaines', 'mêmes', 'as', 'sait', 'tien', 'après', 'delà', "quelqu'un", 'proche', 'ai', "qu'", 'ton', 'lès', 'auquel', 'mais', 'deja', 'lui-meme', 'miens', 'moi-même', 'relativement', 'ainsi', 'celle-ci', 'importe', 'quelques', 'permet', 'que', 'sien', 'préalable', 'diverse', 'quatorze', 'avait', 'parler', 'dit', 'afin', 'déjà', 'peut', 'lui', 'certains', 'derrière', "l'", 'tous', 'restant', 'via', 'merci', 'être', 'tu', 'directement', 'suffit', 'elle-même', 'différent', 'dix-sept', 'assez', 'moins', 'autrement', 'memes', 'y', 'suivre', 'vé', 'vôtre', 'laquelle', 'notamment', 'deux', 'il', 'pouvait', 'ah', 'tels', 'ou', 'et', 'ses', 'nous', 'allons', 'mille', "t'", 'divers', 'dès', 'hi', 'semblaient', 'revoilà', 'six', 'unes', 'parlent', 'certaine', 'plusieurs', 'vous', 'suivante', 'fait', 'seraient', 'elles', 'vôtres', 'les', 'ceux-ci', 'm’', 'lesquels', 'parfois', 'aux', 'parce', 'là', 'différentes', 'egalement', 'chacun', 'tout', 'or', 'auxquels', 'semblent', 'ils', 'aie', 'dixième', 'le', 'premier', 'suis', 'vais', 'rendre', 'na', 'sa', 'deuxièmement', 'tend', 'pres', 'sauf', 'tellement', 'maintenant', 'auxquelles', 'quatrième', 'dedans', 'dans', 'chaque', 'aura', 'dits', 'pour', 'malgré', 'dont', 'diverses', 'treize', 'onze', 'quatre-vingt', 'donc', 'trois', 'lequel', 'retour', 'seules', 'chacune', 'anterieur', 'toi', 'votres', 'voici', 'dire', 'etc', 'alors', 'quand', 'un', 'procedant', 'antérieures', 'peu', 'tenant', 'anterieures', 'parle', 'celui-là', 'ne', 'celui', 'miennes', 'te', 'laisser', 'd’', 'differente', 'car', 't’', 'devant', 'certain', 'vu', 'seule', 'ta', 'depuis', 'cent', 'est', 'sans', 'tenir', 'relative', 'toi-meme', 'hors', 'facon', 'exactement', 'avais', 'cette', 'avons', 'dix', 'tres', 'troisièmement', 'première', 'vos', 'uns', 'différents', "c'", 'spécifique', 'maint', 'quatre', 'douzième', 'partant', 'pourquoi', 'pu', 'envers', 'toi-même', 'tente', 'étant', 'toutes', 'étais', 'etais', 'specifiques', 'auraient', 'entre', 'moindres', 'selon', 'semblable', 'plus', 'cinquième', 'compris', 'sienne', 'puisque', 'rend', 'précisement', 'apres', 'etre', 'cinquante', 'pendant', 'neuvième', 'plutot', 'neanmoins', 'désormais', 'celle', 'faisaient', "n'", 'hem', 'ouverte', 'differentes', 'premièrement', 'quoi', 'derriere', 'telle', 'i', 'lors', 'hé', 'attendu', 'je', 'abord', 'etaient', 'moi', 'tant', 'desquelles', 'voilà', 'directe', 'jusqu', 'nul', 'souvent', 'nôtres', 'lesquelles', 'eh', 'possibles', 'même', 'dessus', 'encore', 'font', 'néanmoins', 'nous-mêmes', 'avoir', 'certes', 'faisant', 'vers', 'seront', 'eux', 'juste', 'cinquantaine', 'suit', 'ont', 'cinquantième', 'soit', 'a', 'hou', 'celles-la', 'autre', 'nôtre', 'elle', 'quarante', 'seulement', 'sent', 'quels', 'si', 'prealable', 'seize', 'elles-mêmes', 'o', 'c’', 'dix-neuf', 'da', 'sinon', 'leur', 'lorsque', 'ouvert', 'vont', 'touchant', 'sera', 'hui', 'n’', 'de', 'notre', 'nouveau', 'outre', 'où', 'revoici', 'quelque', 'stop', 'celles-là', 'chez', 'ait', 'hue', 'leurs', 'possible', 'nos', 'nombreux', 'près', 'concernant', 'quelle', 'également', 'ci', 'voila', 'cinq', 'se', 'pourrais', 'ceci', 'suivant', 'étaient', 'vous-mêmes', 'huitième', 'ma', 'douze', 'suffisant', 'tel', 'mienne', 'dehors', 'cela', 'enfin', 'differents', 'hep', 'telles', 'votre', 'ni', 'elles-memes', 'aupres', 'etant', 'fais', 'peux', 'dite', 'déja', 'au', 'personne', 'très', 'des', 'seul', 'suffisante', 'celles-ci', 'bat', 'soi', 'specifique', 'ceux-là', 'â', 'j’', 'effet', 'celle-la', 'troisième', 'comme', 'quelconque', 'huit', 'bas', 'longtemps', 'sixième', 'sont', 'ces', 'sous', 'revoila', 'malgre', 'puis', 'soi-meme', 'excepté', 'ho', 'suivantes', 'celles', 'me', 'antérieure', 'septième', 'feront', 'meme', 'différente', 'jusque', 'toujours', 'on', 'va', 'quant-à-soi', 'celle-là', ...

# %%
import string

def French_Preprocess_listofSentence(listofSentence):
 preprocess_list = []
 for sentence in listofSentence :
  sentence_w_punct = "".join([i.lower() for i in sentence if i not in string.punctuation])

  sentence_w_num = ''.join(i for i in sentence_w_punct if not i.isdigit())

  tokenize_sentence = nltk.tokenize.word_tokenize(sentence_w_num)

  words_w_stopwords = [i for i in tokenize_sentence if i not in stop and i not in stop_perso]

  #words_lemmatize = [lemmatizer.lemmatize(w) for w in words_w_stopwords]

  sentence_clean = ' '.join(w for w in words_w_stopwords if w.lower() in mots or not w.isalpha())

  preprocess_list.append(sentence_clean)

 return preprocess_list

# %%
french_preprocess_list = French_Preprocess_listofSentence(lemma_sentences)

# %%
french_preprocess_list
# Out:
# ['acheter trop vêtement utiliser mauvais qualité',
#  'cesser promouvoir mode changeant privilégier vêtement durable solide bon qualité',
#  'supprimer méthode sablage vieillir vêtement',
#  'encourager marque produire matière durable naturel recyclée',
#  'lourdement taxer transport pollution fort travailleur',
#  'imposer marque affichage étiquette notation',
#  'changer procédé teinture teinture polluant',
#  'faire recyclage utiliser chute',
#  'arrêter importer produit chine pays respecter environnement droit homme',
#  'aider réapprendre coudre main machine permettre réparer transformer vêtement',
#  'mettre place vrai label certifiant produit respecter condition production écologique humain',
#  'soutenir financièrement création structure réparation vêtement abîmer éviter finir',
#  'interdire marque jeter vêtement neuf',
#  'entreprise polluant éthique vitrine',
#  'développer second sein magasin vêtement neuf',
#  'mieux afficher provenance vêtement matière aller calculer impact carbone vêtement',
#  'production condition travail respectueux matière durable',
#  'magasin marque proposer point collecte vêtement faire don association',
#  'coton produire limiter impact environnement',
#  'arrêter produire vêtement coût jeter lavage',
#  'diminuer manière drastique pollution générer mode pesticide teinture textile',
#  'créer label permettre consommateur savoir acheter',
#  'développer matière marque vendre grand quantité défi production',
#  'informer citoyen danger social éthique environnemental',
#  'contraindre règle production interdire vente produit',
#  'revaloriser métier textile formation souci préservation environnement économie',
#  'supprimer détergent chimique toxique',
#  'encourager échange vêtement troc',
#  'rappeler cliente trop consommer',
#  'produire tissu fabriquer vêtement localement minimum pays européen voisin substance dangereux',
#  'textile résister temps',
#  'enseigne proposer service location vêtement bébé',
#  'continuer encourager communauté échange',
#  'mode critère achat critère vraiment besoin',
#  'produire fibre tisser confectionner vêtement défaut',
#  'privilégier fibre naturel éliminer fibre synthétique',
#  'établir relation constructif éthique fournisseur',
#  'fabriquer tissu matière naturel biologique',
#  'expliquer impact mode industrie textile monde télé enfant école',
#  'développer outil informer consommateur amont aval sensibiliser',
#  'fabriquer produit lieu production matière',
#  'arrêter emballer housse plastique envoi produit magasin emballage',
#  'produire besoin réduire gaspillage',
#  'imprimer étiquette composition entretien in poche pantalon mettre étiquette',
#  'proposer vêtement prix arrêter gonfler prix ensuite pratiquer promotion année',
#  'produire localement matière non animal non polluant',
#  'école éduquer confection vêtement étape patronage matière utiliser teinture',
#  'grand entreprise impliquer projet ex plastique polluant mer',
#  'utiliser magasin ampoule consommation énergie surveiller consommation eau recycler déchet',
#  'sensibiliser population green vouloir responsable',
#  'taxer publicité valoriser physique ralentir consommation',
#  'remettre couture mode',
#  'développer davantage quartier tarif correct',
#  'fin plastique livraison étiquette sac vente cintre merchandising',
#  'récupérer ancien vêtement échange bon celer permettre limiter gaspillage vestimentaire recycler',
#  'vêtement cycle analyse vie maîtriser innover méthode production consommation',
#  'vêtement meilleur qualité réparable',
#  'imposer vêtement',
#  'démocratiser plate forme revente mieux récompenser chaîne revente',
#  'diminuer emballage plastique non recycler utiliser création vêtement achat',
#  'marque encourager enseigne donner défectueux association obliger détruire',
#  'créer collection partir ancien collection',
#  'mener campagne information collège lycée sensibiliser jeune impact négatif mode',
#  'absolument revenir in produire sauver emploi savoir faire améliorer qualité',
#  'magasin récupérer vieux chaussure recycler',
#  'utiliser matière meilleur qualité économie responsable polyester',
#  'développer second main mode recyclée encourageant collecte vêtement porter',
#  'réduire durée transport auprès fabriquer européen prix produit suffisamment abordable',
#  'favoriser filière production local national régional vêtement matière main transport',
#  'obliger marque recycler ancien vêtement principe pollueur payeur',
#  'travailler matériau naturel polluer faciliter recyclage',
#  'marque prôner économie circulaire récupérer vêtement propre marque magasin recycler',
#  'garder collection basique production circuit court',
#  'interdire matière polluant sequin paillette',
#  'tracer empreinte carbone fringue privilégier fabrication local matériau',
#  'faire varier imposition entreprise fonction engagement',
#  'coton culture obligatoire',
#  'recycler vêtement faire collecte textile proposer avantage client forme point cagnotte',
#  'privilégier vêtement accessoire meilleur qualité label éthique devoir polluant',
#  'réduire rythme collection collection saison',
#  'réussir faire échange entrer consommateur forcément côté vente nouveauté',
#  'prévenir accumulation vêtement accessoire valoriser démarche intégrer raccommodage',
#  'contrôler travail interdire enfant respecter usine textile',
#  'arrêter jeter invendu faire profiter association croix rouge enseigne pauvre',
#  'revenir production local',
#  'arrêter mode collection changer concept style fomenter créativité vêtement',
#  'enseigne reprendre vêtement occasion bon état éviter gaspillage favoriser recyclage',
#  'louer vêtement',
#  'privilégier fabrication atelier contrôler',
#  'certifier provenance matière garantir condition décent travail salaire',
#  'sensibiliser marché second main forcément sale synonyme pauvreté jugement valeur',
#  'créer espace revalorisation vêtement occasion grand enseigne atelier couture collecte revente',
#  'faciliter recyclage vêtement proposer ramener vêtement magasin gratuitement année',
#  'réemployer enseigne recréer article pouvoir facilement faire réparer vêtement',
#  'proposer service réparation vêtement magasin',
#  'proposer lieu collecte recyclage vêtement lieu facile accès supermarché gare ville',
#  'vêtement polyester lavage rejeter million tonne plastique mer',
#  'produire grand quantité privilégier qualité savoir faire local maximum pouvoir',
#  'vêtement enfant bébé mixte',
#  'afficher bilan carbone fabrication vêtement',
#  'teinture produit utiliser confection vêtement naturel respectueux environnement',
#  'modèle issu matière produire respect animal',
#  'service couturier ère magasin proposer service réparation local',
#  'privilégier mode intemporel pièce qualité démoder bout saison',
#  'industrie textile développer usine présent ouvrir',
#  'garde robe adapter saison pièce réutilisable long année',
#  'redonner tonne invendu association ex secours populaire faire geste utile bénéficiez fiscal',
#  'préférer marque produire circuit court',
#  'développer produit naturel fabriquer lin coton',
#  'inviter acheter vêtement coton décourager entreprise production synthétique',
#  'favoriser location vêtement éviter achat usage ponctuel',
#  'acheter français cher acheter vêtement venir loin mauvais qualité',
#  'enseigne proposer seconde main marque',
#  'réapprendre jeune coudre réparer vêtement donner envie fabriquer recycler modifier',
#  'proposer carte donner accès avantage produit reconnaître respectueux planète habitant',
#  'revaloriser formation professionnel artisan reconstruire tissu productif',
#  'sensibiliser jeune enfant adolescent mode responsable frugal',
#  'utiliser teinture écologique tourner produit recycler emballage sac',
#  'marque racheter sou forme bon achat vêtement bon état partie magasin',
#  'augmenter produit venir loin réduire produit local',
#  'trouver système recyclage cintre cristal cintre noir plastique finir poubelle',
#  'sensibiliser citoyen consommer pousser entreprise produire mieux vêtement durable solide',
#  'utiliser chute tissu fils recycler ancien vêtement',
#  'sensibiliser consommateur pratique consommation durable',
#  'diminuer taxe entreprise français',
#  'cesser renouvellement trop fréquent collection',
#  'inclure promouvoir politique second main offre commercial',
#  'respecter règle vert prendre nature pouvoir donner fabriquer fonction besoin',
#  'encourager braderie vente article occasion',
#  'éviter cuir végétal majoritairement composer plastique',
#  'consommer article bon qualité clair',
#  'informer public prix vêtement payer cher venir loin informer alternative main',
#  'proposer recycler tissu vêtement trop usager parallèle proposer vêtement main',
#  'favoriser usage proposer location second main vide',
#  'étiquette préciser endroit passer vêtement long chaîne fabrication',
#  'consommer produit utiliser',
#  'apprendre jeune bien acheter qualité bien entretenir savoir recoudre bouton faire ourlet utile',
#  'part prix vêtement consacrer matière travail humain clairement afficher isolé coût profit',
#  'grand marque proposer vêtement qualité résister temps usure lavage',
#  'colis écologique type carton',
#  'réglementer production vêtement éviter invendue marque pouvoir vendre collection durer an',
#  'utiliser produit naturel matière teinture limiter allergie peau',
#  'responsabilise attendre enseigne agir place taxon kilogramme déchet produire',
#  'veiller matière naturel produire surconsommation eau coton tonte violent laine',
#  'production local national produit procédé fabrication sain respectueux environnement',
#  'inciter donner vêtement jeter faire connaître petit marque local',
#  'entreprise participer activement recyclage déchet produire nettoyage déchet créer',
#  'diffuser largement valoriser savoir faire couture rapiéçage recyclage maison textile',
#  'développer campagne sensibilisation impact environnemental mode consommation',
#  'créer box recyclage produit abîmer magasin',
#  'réinventer système achat consommateur responsable proposer article',
#  'savoir venir produit commercialisation habit enfant esclave moderne devoir cesser',
#  'mettre place davantage location vêtement marque',
#  'privilégier matière issu culture biologique nécessiter pesticide eau',
#  'organiser filière recyclage',
#  'arrêter surproduction recycler réellement vêtement lieu enfouir polluer sol',
#  'pouvoir amener vêtement souhaiter boutique recyclage contre bon achat',
#  'développer concept magasin second main marque vêtement luxe',
#  'former génération développement durable changer consommateur métier profondeur',
#  'informer client découpage prix coût fabrication coût transport coût création',
#  'réduire volume production collection capsule baser matériau recycler',
#  'faire pédagogie auprès consommateur comprendre acheter vraiment bon mauvais sens',
#  'vêtement durable usure concevoir qualité quantité',
#  'développer matière chanvre lin laine réduire utilisation matière plastique polyester',
#  'mettre production local affichage évident mode distribution vente ligne',
#  'réduire rythme collection éviter gaspillage',
#  'marque vêtement proposer patron coudre kit tissu',
#  'penser bonne matière naturel recycler',
#  'éviter faire perdre emploi créer transport',
#  'généraliser filière réemploi décor événement défilé salon mode modèle réserve art',
#  'favoriser circuit court produire région',
#  'arrêter grand discours agir concrètement jour jour',
#  'privilégier vêtement occasion',
#  'favoriser achat second main',
#  'proposer vente faire don tissu ancien collection diminuer déchet',
#  'agir amont produire mieux inciter consommateur consommer mieux',
#  'magasine démocratisent second main mettre marque éthique lux inconscient',
#  'proposer accessoire cuir végétal',
#  'prévoir rayon vente vêtement main magasin prêt porter',
#  'limiter consommable strict nécessaire paquet cadeau sac shopping blister',
#  'proposer atelier transformer vêtement occasion remettre goût jour réparer didacticiel',
#  'élever mouton tonte filature laine fibre naturel impact direct',
#  'repenser confection textile localement filière textile',
#  'créer score étiquette vêtement ex alimentaire transparence',
#  'réduire emballage plastique livraison article commande client',
#  'taxer importation massif produit',
#  'revenir collection saisonnier',
#  'arrêter acheter vêtement besoin',
#  'interdire transport aérien entrer zone production zone vente',
#  'encadrer vente privé solde bienvenue marge repère',
#  'éliminer taille zéro pousser mannequin anorexie entretenir idéal nocif général',
#  'acheter vêtement qualité user remplacer mode inspirer raisonnablement',
#  'privilégier circuit court étape produit',
#  'limiter collection redonner vie ancien vêtement hanter rayon magasin',
#  'prendre compte souffrance animal',
#  'produire beaucoup produire bien respect environnement santé travailleur',
#  'relancer industrie filature particulièrement développement fibre recycler',
#  'établir contrôle qualité textile interdire production vente vêtement durée vie trop court',
#  'garantir condition production sain respectueux travailleur',
#  'développer production vêtement matériau durable culture empreinte écologique faible matériau recycler',
#  'limiter voir supprimer produit origine animal ex angora',
#  'recycler vieux vêtement lieu jeter vouloir',
#  'interdire produit respecter animal fourrure duvet',
#  'relancer émission recyclage vêtement',
#  'travailler média diffuser besoin jeter',
#  'joindre force investir recherche développement améliorer filière recyclage',
#  'arrêter créer multiplier collection intermédiaire fin été début automne celer sens',
#  'utiliser matière naturel chanvre lin pouvoir produire loin coton gourmand eau',
#  'utiliser matière naturel non polluant coton bambou innovant déchet raisin ananas bière',
#  'vêtement devoir',
#  'privilégier matière naturel synthétique préférer polyester recycler',
#  'favoriser fabrication local in in recyclant invendu',
#  'produire mieux basique qualité durable responsable in',
#  'réduire réutiliser recycler emballage sac boite chaussure',
#  'taxer livraison inciter consommateur grouper achat revenir achat physique magasin',
#  'imposer norme résistance durée vie tenue textile informer consommateur aller durer mois',
#  'arrêter inciter acheter vêtement publicité',
#  'utilisation paillette matériau pouvoir détacher lavage rejoindre milieu naturel',
#  'accessible innovation matière donner transparence usine production',
#  'interdire projet loi grand marque lux français détruire article invendu fin collection',
#  'relancer industrie textile local responsable',
#  'information consommateur condition travail pays fabriquer vêtement vendre',
#  'utiliser teinture nocif coloris éclatant',
#  'recycler vêtement non utiliser magasin devoir proposer reprise vêtement user échange réduction',
#  'permettre particulier donner vêtement recyclage magasin',
#  'in',
#  'interdire produit chimique irritant vêtement',
#  'mettre place pénalité financier important entreprise utiliser procédé néfaste environnement',
#  'fin vie produit prendre compte degré devenir produit consommateur vouloir',
#  'arrêter utilisation fibre synthétique',
#  'recycler faire collection vieux vêtement',
#  'moderniser autonome approvisionnement',
#  'modifier perception culturel positif lier mode publicité marketing réglementation',
#  'valoriser service réparation entretien vêtement accessoire assurer longévité',
#  'étiquette visible informer lieu production vêtement lieu design',
#  'limiter solde magasin encourager acheter produit mauvais qualité non fabriquer',
#  'créer vêtement partir ancien vêtement recycler',
#  'imposer critère social environnemental animal impossible vendre tee euro',
#  'privilégier circuit court reconnaître temps incroyable industrie textile',
#  'réutiliser vêtement user non désirer',
#  'revenir matière naturel type coton lin laine limiter matière synthétique',
#  'produire cesser produire chine',
#  'marque engager récupérer ancien produit recycler fibre donner association',
#  'éliminer emballage plastique',
#  'indiquer clairement vêtement lieu fabrication',
#  'acheter vêtement',
#  'créer vêtement matière facilement pouvoir consigner réutiliser facilement matière',
#  'limiter nombre collection an',
#  'récompenser entreprise fabrication vêtement acheter matière entreprise français',
#  'revaloriser métier textile',
#  'mesurer réduire empreinte carbone produit contribuer projet hauteur émission résiduel',
#  'arrêter faire fabriquer vêtement pays asiatique',
#  'proposer client sorte consigne vêtement plaire marque engager recycler bon donner',
#  'augmenter proportion article matière recycler biologique',
#  'mettre place système type impact environnemental vêtement chaussure',
#  'matière adapter fort chaleur fluide',
#  'revenir fabrication français qualité prétention',
#  'cintre produit recycler',
#  'tendre fabrication zéro déchet',
#  'envoyer article sachet jeter voir sac litre jour magasin remplir plastique gros',
#  'trouver alternative petit cintre présentation plastique',
#  'arrêter production masse pays lointain revenir confection demande voire mesure',
#  'privilégier matière naturel durable garantir prix transparent',
#  'fabrication revenir produit',
#  'réapprendre consommateur vrai valeur produit enrayer consommation outrance',
#  'arrêter consommer temps besoin changer garde robe',
#  'informer citoyen impact tissu synthétique pollution déverser océan',
#  'pédagogie matière fibre clarifier composition vêtement',
#  'mode',
#  'arrêter faire fabriquer chine servir proposition lire étiquette in chiner',
#  'organiser troc entrer client',
#  'arrêter prêt porter empêcher achat compulsif inutile fabriquer localement',
#  'transformer business modèle fabrique industrie réparer recycler transformer atelier',
#  'boutique travailler réseau stock collectif proposer client production raisonner',
#  'rappeler vêtement bien jetable achat raisonné',
#  'inciter production français soutenir création emploi produit qualité faible valeur',
#  'favoriser production artisan art excellence',
#  'consommateur questionner achat réduire besoin',
#  'produire vêtement condition décent humainement environnement travail salarié condition salarial',
#  'marque assurer droit fondamental humain respecter',
#  'justice français condamner entreprise faire travailler enfant chaîne production',
#  'maintenir mettre disposition base information matière filière existant',
#  'fabriquer français',
#  'proposer second utilisation vêtement transformation facile second usage',
#  'limiter emballage plastique produit emballer individuellement réfléchir meilleur conditionnement',
#  'produire cuir végétal utiliser cuir animal',
#  'intégrer matière biologique approvisionnement local programme pédagogique école mode',
#  'créer étiquette vêtement indiquer coût écologique produit système comparable',
#  'arrêter cintre plastique refuser achat boutique',
#  'proposer collection vêtement composer tissu recycler',
#  'mettre place boutique rayon vêtement porter occasion tarif réduit',
#  'organiser encourager récupération vêtement second main pouvoir réutiliser association type',
#  'développer marché second main mode recyclée encourageant collecte vêtement porter',
#  'davantage coupe adapter morphologie mince droite rond long court',
#  'obliger marque inscrire étiquette origine produit réellement fabriqué',
#  'donner information magasin utilité avantage mode responsable',
#  'mettre place matière textile',
#  'transparence traitement ouvrier atelier rémunération équitable condition travail',
#  'informer consommateur avantage consommer français',
#  'interdire destruction invendu',
#  'transparence origine condition fabrication mieux informer client responsabiliser',
#  'ralentir « saison » collection désigner vêtement « out » mois tard',
#  'montrer utilisateur prendre soin vêtement chaussure prolonger durée vie',
#  'privilégier application donner chance vie vêtement',
#  'artisan accéder système équivalent chèque emploi service promouvoir utilisation savoir faire',
#  'consommer',
#  'finir produire quantité astronomique vêtement mauvais qualité durée vie court',
#  'vêtement meilleur qualité devoir mode jetable faire beaucoup déchet',
#  'marque tendance arrêter proposer robe synthétique euro',
#  'proposer taille grand produit tendance exclure',
#  'éduquer consommateur baser décision achat critère prix critère environnemental',
#  'utiliser emballage arrêter plastique conditionnement vêtement',
#  'baisser coût travail vouloir former métier noble textile',
#  'remettre vêtement circuit offrir second vie',
#  'mettre place buanderie virtuel géant échange vêtement enfant bébé',
#  'éduquer population mettre place loi imposer éthique durable',
#  'arrêter sortir collection jour',
#  'réutiliser affaire potable',
#  'baisser taxe produit responsable recyclé',
#  'interdire importation article produire pays respecter norme environnemental social',
#  'remettre place cours couture collège pouvoir apprendre donner second vie vêtement',
#  'diminuer déchet textile pollution privilégier fabrication européen',
#  'informer public coût écologique économique vêtement logo étiquette',
#  'proposer matière naturel',
#  'initier réemploi vêtement développer créativité',
#  'aider recherche parallèle industriel pouvoir proposer produit naturel accessible',
#  'favoriser taux adapter vêtement limiter impact coût développement concurrentiel',
#  'taxer marque produire mal celer répercuter acheteur expliquer démarche',
#  'lancer concours région créateur in transformer recycler gagner aide création',
#  'réglementer interdire obsolescence programmer textile',
#  'recycler vêtement consommer manière occasionnel occasion',
#  'indiquer provenance matériau consommation requérir production',
#  'favoriser achat internet article qualité durable prix raisonnable supprimer maximum intermédiaire',
#  'interdire destruction article retourner internet',
#  'chérir vêtement entretenir soin lavage réparation optimiser durabilité provenance prix',
#  'proposer cours gratuit couture textile savoir produit bien faire matière',
#  'développer vêtement matière synthétique matière chanvre cultiver',
#  'revaloriser cassé tacher association valeur correspondre entreprise',
#  'louer lieu acheter vêtement porter cérémonie vêtement ski',
#  'sensibiliser grand public méthode ludique impact dévastateur fabriquer vêtement',
#  'travailler matière produit pouvoir vraiment connaître durabilité produit',
#  'promouvoir permettre consommer mieux degré main artisanat faire faire faire réparer transformer',
#  'limiter long transport marchandise',
#  'producteur laine tissu bouton français européen respectueux environnement',
#  'marque proposer vêtement occasion marque achat revente internet magasin',
#  'proposer uniquement cintre bois proposer vente client',
#  'créer collection adapter climat produire petit collection saisonnier adapter saison',
#  'apprendre aller mode transformant vêtement',
#  'imposer score vêtement aliment',
#  'visible petit marque créer créneau beaucoup vertueux',
#  'interdire usage fourrure produit origine animal laine cuir',
#  'mettre place borne récupération magasin pouvoir réutiliser tissu élastique fermeture',
#  'consommer mieux soutenir marque responsable second main',
#  'magasin occasion',
#  'proposer stand mercerie magasin faire reprendre réparer vêtement',
#  'inclure fiche indique empreinte carbone produit comparer quota standard annuel lieu précis fabrication',
#  'marque proposer gratuitement coût réduit réparation transformation produit',
#  'vêtement issu recyclage',
#  'neutraliser pub donner envie vêtement autoriser pub marque saison max',
#  'proposer vêtement adapter taille ex couture tee pouvoir grandir',
#  'réduire déchet produire favoriser recyclage marché occasion industrie mode devoir réinventer',
#  'marque reprendre vêtement euro symbolique recycler revendre second main',
#  'convaincre arrêter mode acheter vêtement bon qualité pouvoir servir année année',
#  'accompagner financièrement innovation recherche textile propre recyclé',
#  'privilégier article fabriquer respect environnement',
#  'ajuster plan collection terme calendrier esthétisme produire mieux',
#  'fabriquer localement fois proposer client rapporter vêtement usager pouvoir retraiter localement',
#  'interdire matière animal cuir fourrure',
#  'production textile qualité environnement favoriser emploi qualifier',
#  'fourrure biodégradable durable label animal',
#  'baisser produit fabriquer',
#  'sortir système saison contretemps ailleurs promouvoir fabrication local commande',
#  'faire changer habitude consommateur acheter raisonné qualité durable',
#  'proposer vêtement lieu fabrication clair consommateur',
#  'mettre taxe carbone vêtement provenance zone géographique extérieur union européen',
#  'refuser travail enfant',
#  'bourse vêtement',
#  'réduire production consommation vêtement',
#  'marque allier aider industriel donner vrai part marché',
#  'envisager louer vêtement rythme envie consommer qualité créativité',
#  'créer base donnée évaluation qualité marque pièce marque durer année',
#  'produit français compétitif produit étranger',
#  'mettre place taxe site chinois type',
#  'augmenter prix euro vouloir rien pays pauvre pouvoir sortir remettre prix',
#  'trouver alternative emballage plastique cintre plastique trop présent industrie mode',
#  'créer label éthique dignité fabrication matière non polluant respect animal transport non polluant',
#  'enseigne racheter reprendre produit revendre occasion',
#  'prix vêtement produire masse ensuite solder',
#  'revoir mode consommation strict minimum pouvoir permettre',
#  'réduire coût transport',
#  'utiliser matière naturel lin coton éviter maximum lier fibre synthétique',
#  'savoir faire métier désolant voir nombre vêtement mal couper porter rue',
#  'proposer sac papier gratuit cintre carton recycler limiter plastique',
#  'sensibilisation école primaire campagne publicitaire adulte grand enseigne magasin',
#  'interdire sachet plastique bouton sequins perle rechange',
#  'utiliser vêtement user réaliser vêtement recycler',
#  'utiliser ressource naturel recycler nuire pays voie développement',
#  'mettre place filière court neutre carbone proposer rémunération producteur',
#  'mettre place taxe écologique textile acheteur producteur',
#  'limiter article commande internet pouvoir emballer sac plastique',
#  'aider filière lin chanvre ressource local français',
#  'proposer habit second main qualité garantir',
#  'faire pédagogie réparation devenir réflexe',
#  'pouvoir mesurer précisément impact environnemental étape production logistique',
#  'jeter vêtement invendu recycler offrir association produire petit quantité',
#  'arrêter acheter vêtement user ancien besoin paire chaussure',
#  'encourager entreprise textile changer communication mettre qualitatif',
#  'proposer alternative livraison exemple utiliser méthode acheminement écologique',
#  'remettre circuit vêtement second main bon état contre réduction utiliser endommagé faire',
#  'limiter exportation',
#  'utiliser matière facilement bannir matière source déchet pollution plastique colorant',
#  'proposer gamme vêtement réaliser partir cuir cuir raisin recyclé',
#  'condition travail usine produire vêtement',
#  'obliger fabricant proposer collection produit',
#  'mode couture arrêter collection faire vêtement devoir temps mode',
#  'fabriquer',
#  'marque faire effort proposer vêtement étique durable second main accessible',
#  'exiger mise place green score produit textile image',
#  'communiquer empreinte environnemental fabrication vêtement action mettre place réduire',
#  'imposer marque transparence étiquette fabrication coton eau impact carbone',
#  'obliger marque intégrer réseau second main recyclage magasin',
#  'récupérer vêtement porter recycler créer modèle',
#  'réutiliser chute tissu disponible fabriquer vêtement',
#  'encourager location vêtement',
#  'restructurer formation filière stylisme couturier mieux répondre demande local durable',
#  'supprimer emballage plastique livraison favoriser papier soie papier kraft',
#  'reprendre chaussure usager recycler',
#  'créer boutique rénover vêtement ajout imprimé dentelle top pull niveau coude',
#  'produire pays européen',
#  'réutiliser produit vêtement tissu mercerie produire fabriquer localement',
#  'rayon occasion magasin vêtement reprendre ancien modèle',
#  'limiter nombre collection mode enfant devoir renouveler garde robe grandir',
#  'consommer local consommer français faire marcher petit producteur sou traiter cesse',
#  'inciter production vêtement faible consommation pollution eau',
#  'ralentir cadence collection solder outrance écouler stock solution',
#  'permettre créer davantage magasin second main',
#  'marque proposer sein enseigne rayon second main produit',
#  'supprimer emballage basique',
#  'privilégier matière naturel pesticide',
#  'arrêter promotion outrance pratiquer prix',
#  'accélérer sujet cuir industrie cuir polluant cruel état',
#  'arrêter fournir coût non éthique chine ailleurs assurer respect droit homme',
#  'généraliser étiquette informer impact émission eau énergie mode vente magasin',
#  'concerter acteur mouvement « » mettre place action',
#  'créer vêtement intemporel besoin changer année responsable',
#  'titre vente privé aménager priver exemple incitation financier',
#  'accompagner marque développement support réparation remettre neuf',
#  'faire sorte constamment améliorer recyclage vêtement chaussure',
#  'obliger fabricant revendeur indiquer provenance matière utiliser vêtement',
#  'proposer collection réduire quantité limité générer stock',
#  'produire mieux bon produit prix rémunération développer invendu',
#  'responsabiliser marque cycle vie produit réparation second main valorisation recyclage',
#  'mettre place solution location vêtement porter fois soirée mariage',
#  'utiliser lin produit arrêter synthétique',
#  'créer vêtement matériau',
#  'parent sensibiliser enfant portée environnemental achat',
#  'habiller mieux',
#  'apprendre enfant porter vêtement second main',
#  'acheter seconde main recycler permettre aider démunir',
#  'repenser mention in pouvoir apposer produit in',
#  'fabriquer français refaire partir économie faire travailler concitoyen',
#  'commerce proximité',
#  'faciliter revente recyclage vêtement magasin ex boutique payer récupérer vêtement',
#  'marque développer propre réseau achat vente produit occasion intégrer recyclage production',
#  'vendre prix article comporter petit défaut nombre savoir coudre',
#  'encourager filière producteur lin coton laine alpaga français travailler créer vêtement',
#  'fabriquer local arrêter jeter vêtement saison habit devoir porter année',
#  'répondre besoin non créer envie spontané',
#  'concevoir fabriquer produit meilleur qualité devoir valoriser qualité savoir faire français',
#  'respecter droit homme conception mise rayon porte chose honte',
#  'encourager grand magasin corner dédier petit série fabriquer',
#  'collection profond acheter volume renouvellement collection',
#  'mode in accessible bourse modeste',
#  'refuser acheter marque respecter planète vie humain animal',
#  'marque reprendre ancien vêtement donner association',
#  'qualité prix abordable donner envie porter in vouloir',
#  'arrêter promotion perpétuel proposer produit vrai prix rééduquer consommateur valeur chose',
#  'proposer bac collecte spécialement dédier chaussure chausson accessoire sac main ceinture collant',
#  'indiquer empreinte carbone étiquette',
#  'marque réintégrer retouche réparation coeur offre meilleur service client',
#  'privilégier politique consommation',
#  'pousser recyclage invendu textile',
#  'maison vieux article client récupérer matière client prix',
#  'indiquer clairement étiquette vêtement prix produit',
#  'valoriser préserver métier art français partir retraite expatrier faire',
#  'consommer occasion',
#  'reprendre vêtement porter offrir client fonction nombre pièce poids',
#  'sensibiliser acheteur payer qualité emploi éthique acteur consommateur',
#  'proposer produit lancer fabrication industriel produire commander',
#  'chaîne production textile fibre naturel laine chanvre lin filage tissage teinture confection',
#  'donner possibilité client ramener vêtement porter boutique faciliter recyclage',
#  'recenser opportunité reprise activité filière recherche soutien',
#  'créer « » mode permettre consommateur évaluer facilement impact social environnemental vêtement',
#  'interdire production vêtement enfant proposer réglementation salaire pays',
#  'étiquetage précis origine composant lieu fabrication produit textile',
#  'favoriser qualité quantité communiquer consommer cher beaucoup économique',
#  'valoriser art manuel couture tricot fibre naturel local produire région',
#  'fabriquer local',
#  'arrêter solde pousser marque transparence prix acheter prix',
#  'obligatoire certification garantir absence composé chimique dangereux santé',
#  'meilleur vêtement matière lieu fabrication',
#  'transparence condition fabrication produit sanitaire salaire droit syndicat',
#  'coton protéger agriculteur',
#  'produire vêtement bon taille éviter renvoi inutile produire local bout terre',
#  'proposer joli armature matière naturel coton lin',
#  'afficher clairement magasin site vêtement information condition production',
#  'transparent totalité article marque vendre grand surface',
#  'proposer espace second main vêtement réutilisable invendu',
#  'communiquer innovation réalisation modèle',
#  'réutiliser emballage tampon sac bout utilisation sac remettre cadeau',
#  'fabriquer chaussette',
#  'éviter proposer collection semaine',
#  'boîte collecte vêtement magasin destiner association étranger',
#  'boutique cesser faire fabriquer outrance faire prix année pousser consommation',
#  'privilégier bambou produit naturel arrêter matière synthétique',
#  'abonnement marque habit enfant client apporter vêtement trop petit échanger grand',
#  'privilégier second main',
#  'utiliser emballage envoi colis client magasin',
#  'trouver alternative colorant ultra polluant jean',
#  'produire trouver matière empreinte carbone',
#  'fabriquer matière local',
#  'vendeur produit neuf capable proposer solution recycler produit luire donner second vie',
#  'privilégier contact commerçant quartier commander internet',
#  'publicité',
#  'arrêter plastique col chemise récupérer attache métallique organiser collecte bouton',
#  'transparence étiquette article eau utiliser coton pesticide impact carbone fabriquer',
#  'proposer service réparation magasin manière systématique',
#  'mettre place malus entreprise fabriquer bout monde respecter salarié',
#  'in vraiment faire',
#  'faire cher',
#  'fabriquer localement',
#  'utiliser dénicheur initiative aider vouloir lancer découvrir simplement initiative',
#  'proposer service reprise vêtement second main marque moindre coût',
#  'favoriser recyclage vêtement',
#  'favoriser marque pratique vertueux matière qualité produire pesticide main oeuvre payer décemment',
#  'créer échange recyclage ancien vêtement redistribution vêtement jeter',
#  'rebâtir système formation technique industriel nécessaire filière territoire national',
#  'mettre place collectivité lieu pouvoir vendre vêtement action information global',
#  'brader invendu vêtement tacher invendable distribuer charité',
#  'utiliser numérique créer collection demande éviter surproduction garder valeur travail',
#  'éviter fabriquer étranger réduire pollution exploiter main cher',
#  'empêcher achat coton venir entreprise utiliser vergogne travail forcer travail enfant',
#  'vêtement intemporel jeter bout an lieu ‘ échange vêtement',
#  'proposer revente article second main',
#  'fabriquer maximum limiter empreinte carbone production',
#  'inventer filtre machine laver',
#  'arrêter croire modèle surconsommation année durable planète',
#  'privilégier maximum matière naturel polluant confection vêtement',
#  'créer incitation financier fiscal entreprise mode durable vendre prix concurrentiel',
#  'travailler total produit champ vêtement magasin',
#  'interdire programme fidélité',
#  'préférer matière naturel matière',
#  'avancer chemin économie circulaire second main location',
#  'arrêter envoyer colis magasin produit carton',
#  'sortir cycle insensé collection an transformer mode industrie service non perpétuel nouveauté',
#  'tarif vêtement prix favoriser achat produit faire',
#  'marque proposer vêtement rapiécer retailler réajuster correspondre mode polluer',
#  'arrêter créer mode envie limiter achat besoin vêtir chausser',
#  'vêtement recycler réutiliser site vendeur',
#  'consommer mieux',
#  'développer troc occasion boutique',
#  'fabriquer localement matière issu commerce équitable mode respectueux environnement',
#  'faire invendu don camp migrant participer aspect social gouvernance développement durable',
#  'sensibiliser consommateur campagne engager chiffre clé',
#  'mode responsable financièrement accessible milieu social',
#  'capable proposer second vie vêtement échange vente recyclage',
#  'arrêter taille adulte enfant adulte aimer porter vêtement',
#  'bannir produit toxique peau nuisible environnement fabrication vêtement',
#  'fabrication',
#  'produire série limité voire mesure',
#  'faire shopping penser',
#  'développer recherche matière végétal lutter contre animal',
#  'donner moyen consommateur informer correctement savoir bien agir habiller responsable',
#  'privilégier matière organique naturel arrêter utiliser produit chimique fabrication textile',
#  'production',
#  'favoriser vente vêtement second main vêtement circulation',
#  'site vente ligne indiquer origine vêtement chaussure accessoire vendre',
#  'arrêter faire collection aller revenir pièce basique',
#  'interdire matière non écologique autoriser coton lin plante veiller faire surproduction',
#  'développer principe fabriquer trop vêtement jeter',
#  'privilégier matière naturel lin coton laine recyclée',
#  'reprendre industrie textile chanvre',
#  'valoriser fabriqué pari',
#  'production in',
#  'développer second main grand enseigne recycler revendre',
#  'reprendre vieux recycler',
#  'utiliser colorant solvant origine végétal biodégradable',
#  'développer vrai économie circulaire vêtement devenir propre matière utilisation',
#  'magasin vêtement reprendre ancien article client revendre magasin corner second main',
#  'expliquer entreprise recyclage solution absolu impérativement réduire consommation',
#  'casser idée recevoir fibre naturel écologique polyester',
#  'organiser recyclage déchet textile parisien',
#  'détruire concept peine porter démodé',
#  'production graine champ vêtement finir',
#  'autoriser vente vêtement cas connaissance fournisseur marque final',
#  'taxer jamais vêtement identique gagner salaire promouvoir consommation outrance',
#  'industriel recentrer économie circulaire intégrer recyclage produit cycle production',
#  'baisser taxe production français charge social taxe production augmenter taxe',
#  'trouver alternative blister sachet plastique emballer article livraison',
#  'marque racheter vêtement occasion propre marque gérer site occasion téléphone',
#  'vêtement uniquement partir matière recycler coton laine écologique',
#  'favoriser échange troc vêtement acheter neuf',
#  'recycler vieux vieux maillot donner vie',
#  'privilégier matière lin ortie jute coton biologique matière recycler',
#  'inventer vente second main mode magasin joli pièce instaurer permanent saison fin solde',
#  'remettre savoir faire manufacture travers bel entreprise',
#  'arrêter production fourrure cuire proposer alternative consommation faux fourrure',
#  'favoriser système troc local',
#  'éviter tromper taille site grâce outil',
#  'créer pouvoir adapter prise perte poids racheter',
#  'privilégier matière naturel éviter matière synthétique',
#  'proposer janvier maillot bain juillet produit arriver magasin envie',
#  'marque reprendre vêtement occasion pouvoir réparer réparer revendre boutique',
#  'recycler réparer réemployer',
#  'rémunérer prix travailleur travailleuse fabriquer vêtement',
#  'généraliser système don invendu partenariat association pouvoir public',
#  'vêtement fabriquer matériau durable pantalon dur an',
#  'organiser point collecte récupération vêtement sou forme échange reprise bon',
#  'payer prix couturière couturier',
#  'obliger boutique utiliser climatisation hiver fermer porte scandaleux perte énergie',
#  'diffuser information décharge ciel cf recyclage tissu',
#  'réduire distance exportation production réduire émission gaz serre',
#  'créer label identifiant entreprise mode textile mettre place circuit production',
#  'mettre boutique rapide produire flux tendre éviter perte destruction',
#  'favoriser matière durable qualité jeter saison résister usage',
#  'attribuer note marque critère social environnemental chaîne valeur inclure fournisseur',
#  'vêtement meilleur qualité onéreux beaucoup durable temps',
#  'ralentir rythme changement tendance forme couleur vêtement ringard saison',
#  'réduire fréquence production textile besoin nouveauté magasin semaine',
#  'privilégier mesure consommer mieux',
#  'mieux informer acheteur provenance matière lieu coût fabrication',
#  'clair impact environnemental eau ressource produit',
#  'privilégier recyclage matière noble français lin chanvre ramie laine',
#  'arrêter collection court durée privilégier indémodable pouvoir racheter heureux qualité',
#  'promouvoir application type consommateur pouvoir acheter connaissance cause',
#  'pouvoir rapporter vieux abîmer bon taille magasin faire recycler',
#  'éduquer impact environnemental',
#  'développer vrai écosystème occasion magasin choix acheter neuf occasion',
#  'valoriser marque engager faveur consommation responsable origine tissu contrôle usine',
#  'prévoir cycle vie complet vêtement origine reprise collecte tissu filière recyclage',
#  'arrêter produire collection jour jeter brûler invendu voir',
#  'travailler odeur textile recyclé fort désagréable',
#  'arrêter fabriquer vêtement bout planète industrie textile',
#  'développer concertation marque recyclage fibre textile',
#  'développer offrir textile type éviter coton favoriser lin modal matière recycler',
#  'préciser impact environnemental fabrication produit étiquette',
#  'produire localement limiter chemin parcourir textile',
#  'stopper',
#  'appuyer financièrement récupérateur textile encourager création filiale recyclage textile',
#  'reconsidérer besoin moyen production étape création habit',
#  'éviter déchet inutile cintre attache prix chose clip plastique réduire étiquette',
#  'fabriquer vêtement devoir temps éviter jeter reproduire cesse',
#  'produire fonction demande',
#  'favoriser collecte vêtement magasin vue recyclage vente vêtement occasion',
#  'grand diversité concerner égérie mannequin grand moyen petit menu mince rond',
#  'matière écologique issu commerce équitable',
#  'réfléchir organisation économique mondial limiter interdépendance économique pays',
#  'favoriser circuit court fabrication vêtement',
#  'penser recyclage recyclage petit prix',
#  'favoriser éviter stock grand quantité stock',
#  'concevoir collection circuit court composant responsable recyclé',
#  'réutiliser recycler vêtement tissu refaire chose usager penser association',
#  'marque arrêter produire grand échelle répondre besoin produire mieux',
#  'ralentir rythme production',
#  'créer loi mode pouvoir pénaliser lourdement marque respecter',
#  'programme recyclage vêtement fréquent pouvoir donner bon achat',
#  'label in garantir production local induire erreur consommateur',
#  'proposer reprise vêtement usager propre non déchirer contre bon achat magasin minimum achat',
#  'indiquer origine géographique fibre lieu fabrication vêtement étiquette différencier produit',
#  'aide financier entreprise français inciter production local baisse coût salarial investissement',
#  'arrêter faux promotion permanent pousser surconsommation proposer prix',
#  'instaurer cours couture collège enseigner réparation fabrication vêtement',
#  'réfléchir transition inclure pays pauvre exportateur matière tissu vêtement',
#  'utiliser colle naturel étiquette sac ex colle os',
#  'qualité intemporel fibre synthétique vêtement pouvoir servir enfant',
#  'ouvrir magasin seconde main enseigne national',
#  'obliger marque respecter soutenir transition écologique',
#  'valoriser avantage diversité origine âge morphologie campagne publicité défilé vaincre racisme',
#  'valoriser matière biologique production textile soucieux préservation environnement',
#  'fabriquer produit solide devoir voire garantir durabilité',
#  'arrêter proposer vêtement stylé vieux jeune fille obèse vouloir péter classe',
#  'privilégier vente magasin non internet aller créer emploi',
#  'produire bon quantité vêtement',
#  'apporter transparence chaîne logistique industrie textile permettre consommation faire choix éclairer',
#  'choisir matière procédé limiter impact environnemental production filière',
#  'ouvrir boutique faire troc vêtement condition client jeter payer',
#  'proposer réduction fin collection enseigne vêtement textile jean blouson',
#  'produire tissu écologique certifié ® standard gage contrôle étape traitement vêtement',
#  'privilégier création issu produit recycler local',
#  'développer production correspondre demande consommateur devoir éduquer apprendre patience',
#  'informer impact livraison domicile',
#  'permettre recyclage vêtement accessoire non vendre réutiliser matière chose',
#  'apprendre consommer mieux passer matière naturel éthique marque acheter',
#  'repenser consommer besoin non publicité inciter acheter',
#  'magasin proposer point collecte vieux vêtement trier faire second main recyclage état',
#  'proposer vêtement fabriquer partir matière naturel coton lin viscose',
#  'prendre compte bilan humain production vêtement respect condition travail âge minimum',
#  'informer consommateur impact écologique fabrication acheminement livraison vêtement score',
#  'proposer produit fabriquer information visible origine produit',
#  'proposer vêtement qualité français prix abordable cas réduire intermédiaire',
#  'promouvoir site proposer recevoir surplus contre bonus achat',
#  'privilégier modèle unique déclinable qualité rapport collection saison',
#  'impérativement mettre produit non transformer produit circuit court créer label simple',
#  'revenir mode raisonnable vêtement qualité finir haillon',
#  'limiter nombre collection an',
#  'inventer partenariat agriculteur français créer matière textile ex lin français',
#  'transparence fabrication lieu fabrication indiquer transport utiliser origine matière',
#  'informer influençable marque désastre écologique créer vouloir mode',
#  'arrêter emballer vêtement plastique livraison opter matière',
#  'favoriser matière naturel gourmand eau rémunérer justement travail confection tissu vêtement',
#  'utiliser matière naturel bambou coton soie éviter particule plastique retrouver océan',
#  'revoir mention in trompeur modifier loi sujet',
#  'proposer produit français prix raisonnable',
#  'développer partenariat entrer marque atelier couture pouvoir réparer vêtement',
#  'envoyer produit correspondance emballer vêtement sachet plastique',
#  'créer mode arrêter exploiter animal',
#  'obligatoire loi secteur achat vente textile second main magasin grand enseigne',
#  'arrêter faire argent penser bienveillance prévaloir échange prévaloir circulaire',
#  'mode inclusive répondre besoin situation handicap prix abordable',
#  'relancer cours travail manuel enfant apprendre coudre bouton faire ourlet réparer bien cuisiner',
#  'investir outil industriel français européen capable revaloriser déchet textile fibre qualité',
#  'limiter consommation plastique magasin cintre emballage',
#  'repenser mode arrêter réduire production vêtement remettre qualité plan',
#  'imposer cadre législatif beaucoup strict social environnemental grand marque',
#  'arrêter courir saison pleinement vivre saison imposer',
#  'responsabiliser consommateur non changer jour industrie textile énormément',
#  'utiliser matière qualité proposer vrai grand taille modèle',
#  'obliger hypermarché vendre produit non non',
#  'acheter louer vêtement',
#  'rémunérer travailleur mode prix',
#  'renforcer qualité vêtement améliorer épaisseur fils densité tissage qualité couture',
#  'privilégier troc réemploi',
#  'indiquer clairement étiquette lieu fabrication vêtement',
#  'finir faux solde année produit créer uniquement vendre',
#  'concentrer finition vêtement utiliser accessoire solide ex fermeture durable',
#  'donner dernier chance produit défectueux faire remise',
#  'légiférer respect homme environnement importer lieu géographique exploiter',
#  'obliger marque reprendre vêtement usager marque corner occasion magasin',
#  'renseigner client impact écologique social économique produit informer mal bien consommer',
#  'informer consommateur bon comportement fiscal social entreprise',
# ...
#  'valoriser achat vêtement occasion autoriser vente vêtement durable lavage réparable',
#  'limiter utilisation textile nocif obliger industriel utiliser taux minimum textile',
#  'proposer vêtement morphologie lutter contre industrie textile',
#  'arrêter produire vêtement jetable mauvais qualité associer surproduction',
#  'favoriser éviter surplus stock',
#  'absolument arrêter promouvoir vêtement accessoire contenir produit provenir animal laine fourrure cuir',
#  'produire mieux produire perdre habitude renouvellement article boutique régulièrement',
#  'mettre place suivi engagement prendre marque assurer agir opération communication',
#  'imposer taxe important entreprise faire fabriquer ligne vêtement étranger',
#  'inciter transparence meilleur affichage consommateur savoir acheter',
#  'saison an marque',
#  'supprimer programme fidélité incitation surconsommation découler vente privé',
#  'arrêter faire appel intermédiaire exploiter population produire scandale',
#  'valoriser pratique recours propre éthique travailleur environnement économe eau',
#  'produire stock réduire coup stockage surproduction proposer grand gamme taille',
#  'détaxer vêtement produire localement',
#  'inciter acheter quantité',
#  'étiquette produit emballage plastique',
#  'proposer vêtement devoir temps fabriquer manière responsable localement vendre prix',
#  'mettre fin cintre sac plastique approvisionnement magasin',
#  'soutenir financièrement atelier confection français permettre développer',
#  'utiliser matériau naturel laine soie coton vérifier production responsable',
#  'inciter client intéresser provenance fabrication vêtement passer prisme quantité qualité',
#  'visible étiquette matière utiliser origine végétal chimique pays production',
#  'arrêter solde pousser surconsommation jour promotion année',
#  'recycler chute rebut production prêt porter',
#  'imposer entreprise mesurer impact social environnemental produit publier chiffre public',
#  'production pays obliger condition rémunération correct travail faire',
#  'privilégier qualité vêtement pouvoir durer revendre recyclé',
#  'fournisseur utiliser plastique article procéder recyclage cintre plastique',
#  'repenser filière développer alternative cuir cuir végétal bel qualité laine',
#  'mettre place équivalent mode orienter consommateur choix durable',
#  'valoriser recyclage tissu exemple bac collecte recycler magasin',
#  'créer filière recyclage fiable réaliste chaussure beaucoup vêtement chaussure',
#  'favoriser matière issu recyclage vrai solution jour',
#  'donner stock invendu association',
#  'confection vrai talent domaine',
#  'donner second vie vêtement bon état pouvoir porter',
#  'arrêter multiplication étiquette vêtement marque remplacer code',
#  'arrêter décoration vêtement paillette impact négatif santé environnement',
#  'mieux expliquer consommateur site étiquette label',
#  'systématiquement informer consommateur origine matière lieu confection vêtement',
#  'arrêter proposer mode saison contribuer consommation effréné vêtement',
#  'marque penser recyclage créatif vêtement fin vie invendu',
#  'diminuer nombre collection an réduire impact écologique proposer meilleur qualité quantité',
#  'marque accepter communiquer transparence application audit',
#  'arrêter fabriquer acheter bien consommation courant utiliser réparer existant énorme quantité',
#  'produit français produit respecter animal long durée bambou polaire',
#  'conception vêtement viable marque engager planète',
#  'résistance durée vie vêtement critère principal conception',
#  'net impôt revenu générer revenu second main revente article général',
#  'accessible mode second main',
#  'produire créer utile responsable humain nature',
#  'collection réduire saison coupe style intemporel devoir traverser génération',
#  'marque proposer collection choix tenter acheter',
#  'faire meilleur qualité quitte payer cher vêtement utilisable année',
#  'filière privilégier qualité durabilité produit',
#  'proposer maximum recyclage vêtement usager sensible',
#  'mettre place affichage type vêtement prendre compte aspect environnemental social',
#  'obliger marque afficher empreinte carbone article information condition travail fabrication',
#  'faire vente prix unique abordable petit bourse genre euro',
#  'marque inciter consommateur revoir consommer local éthique',
#  'assurer donner véritable dignité pièce production conception',
#  'limiter parcours kilométrique vêtement privilégier production local',
#  'arrêter coudre étiquette vêtement place imprimer papier recycler tissu',
#  'développer gamme écologique éthique comporter taille permettre alternative achat',
#  'finir confection mauvais qualité fabriquer ailleurs',
#  'proposer option envoi sac plastique stocker vêtement',
#  'oublier coût humain travers total transparence complet',
#  'recycler vêtement user ramener vêtement profiter avantage acheter pièce',
#  'éviter nettoyage sec polluant',
#  'transformer vêtement invendu grand marque réutiliser collection',
#  'boycotter marque enseigne engager',
#  'arrêter faire collection saison',
#  'définir label production éthique socialement travail enfant salaire assurance santé ouvrier',
#  'utiliser tissu vêtement recycler uniquement créer inventer dessiner partir exister',
#  'développer solution emballage réutilisable',
#  'organiser remise circuit seconde main réutiliser vêtement occasion trop endommager recycler nouveauté',
#  'revaloriser travail fournir création production vêtement prendre conscience accepter prix',
#  'favoriser utilisation revente habit recycler entreprise lux',
#  'réduire in produit accessible consommateur aider entreprise',
#  'revaloriser lien entrer citoyen artisan couturier redonner valeur travail',
#  'imposer transparence matière fabrication marque luxe',
#  'grand distribution jeune styliste proposer vêtement recycler',
#  'promouvoir court circuit matière venir fabriquer',
#  'changer sac plastique mettre lot culotte filet exemple',
#  'action concret sincère part entreprise vrai volonté bien faire non accroître capital',
#  'arrêter green promouvoir matière',
#  'réduire nombre collection an limiter surconsommation',
#  'proposer produit second main marque',
#  'article arriver magasin emballer pochette plastique usage unique',
#  'éviter vêtement',
#  'utiliser matière naturel respectueux nature recycler biodégradable solide chanvre exemple',
#  'économie circulaire location vêtement possession vente second main',
#  'tissu qualité déformer lavage durabilité vêtement',
#  'valoriser marché occasion',
#  'trouver solution recyclage vêtement porte exemple donner boutique contre bon achat',
#  'indiquer pays région fabrication vêtement étiquette côté taille prix',
#  'sensibiliser consommateur sujet jeune âge déployer action concret école',
#  'faire publicité orienter différemment orienter achat mieux penser',
#  'utiliser fibre naturel',
#  'modifier consommer alimenter mettre lobby échec gouvernement impuissant',
#  'éduquer lavage froid séchage air',
#  'utiliser matériau nocif environnement type retrouver eau',
#  'produire localement pouvoir ensuite revendre prix accessible',
#  'proposer solution vêtement pouvoir utiliser promotion circularité',
#  'taxer produit venir pays condition social environnemental acceptable',
#  'donner client garantie condition travail fabriquer vêtement',
#  'inciter ramener vêtement usager échange réduction collection précédent vendre ligne année',
#  'éviter commande ligne trop cintre trop emballage plastique',
#  'permettre donner vêtement second vie proposer corner dédier magasin économie circulaire',
#  'absolument mettre valeur initiative positif marque taille uniquement grand groupe',
#  'afficher nombre kilomètre parcourir vêtement étiquette',
#  'entreprise textile définir raison engager démarche entreprise mission',
#  'favoriser utilisation fibre végétal',
#  'acheter intelligemment local artisanal',
#  'marque reprendre vêtement porter échange bon achat pouvoir recycler revendre bon état',
#  'développer outil ligne aider client commander taille coup limiter client',
#  'éduquer enfant choix vêtement matière lieu production durabilité',
#  'rouvrir boutique limiter envoi colis',
#  'revaloriser matière noble français lin chanvre',
#  'arrêter présenter jeune icône mode encourager correspondre morphologie inaccessible',
#  'faire mode arrêter adapter corps femme représenter',
#  'proposer rapporter article usager recycler',
#  'mieux afficher composition produit condition fabrication faciliter choix éthique écologique',
#  'recycler habit vendre main',
#  'donner second vie invendu réutiliser chute créer chose donner association',
#  'payer correctement employé',
#  'proposer service réparation tissu accessoire',
#  'obliger entreprise indiquer nom usine travailler site étiquette',
#  'diminuer charge industriel français compétitivité',
#  'cesser produire textile devoir responsable mode urgent',
#  'manière consommer vêtement faire réparer acheter second main',
#  'protéger consommateur simili ananas cactus pomme composé plastique',
#  'moyen contrôle transparent accessible droit fondamental réglementation social environnement santé sécurité',
#  'faire don donner famille habit servir',
#  'arrêter jeter produit défectueux portable proposer petit prix bien donner association',
#  'essayer réduire maximum matière plastique',
#  'recréer filière formation disparaître pouvoir produire',
#  'tisser fabriquer davantage local',
#  'proposer produit prix in',
#  'faire collection matière durable meilleur qualité',
#  'stopper production vêtement mauvais qualité remplacer matière colorant écologique durable',
#  'recycler ancien collection remettre rayon an imaginer',
#  'revenir échange commercial norme strict niveau environnement droit social fin dumping',
#  'mettre place magasin friperie inciter citoyen acheter vendre vêtement',
#  'consommateur informer vrai prix vêtement reverser étape acteur',
#  'acheter réellement besoin porter arrêter achat coup rester placard',
#  'produire quantité renouveler collection',
#  'interdire produit nocif teinte tissu tannage cuir',
#  'faire travailler couturière couturier faire réparer jeter vêtement',
#  'marque faire test durabilité produit vendre',
#  'optimiser transport approvisionnement matière réduire transport long pollueur',
#  'réutiliser tissu vêtement usager',
#  'arrêter envoyer catalogue publicité papier client fidèle',
#  'créer atelier couture cliente apprendre transformer garde robe broderie coussin',
#  'encourager second main solution viable planète marque devoir proposer rayon',
#  'concevoir collection évolutif faire réflexe consommateur fabricant',
#  'pouvoir recycler vêtement maroquinerie chaussure territoire polluer',
#  'entreprise mode proposer produit alimentation',
#  'chaussure adapter morphologie pied extra plat large gros cou gonfler',
#  'produire vêtement impacter négativement environnement électricité retrouvable produit chimique',
#  'faire mieux',
#  'interdire enseigne produire collection exclusif dédier',
#  'obliger marque indiquer clairement pays confection vêtement',
#  'stopper utilisation cuir cachemire plume produit végétal permettre faire souffrance animal',
#  'transporter marchandise train',
#  'arrêter produit luxe vivre expérience lux papier plastique',
#  'faciliter recyclage vêtement',
#  'produire davantage local recycler invendu proposer collection',
#  'sensibiliser français vie revendre chiner coudre acheter neuf matière recycler polluant',
#  'éviter collection démodé mettre rayon prix exorbitant',
#  'apprendre réparer vêtement',
#  'mettre fin solde promotion pousser acheter vêtement mauvais qualité polluant',
#  'acheter basique durable louer joli pièce temporairement continuer amuser',
#  'augmenter part vêtement faire partir matière recycler',
#  'mode changer prendre compte ressource nécessaire fabriquer vêtement',
#  'marque contraindre recycler céder gracieusement invendu sou peine sanction financier',
#  'possibilité recycler achat magasin achat effectuer',
#  'produit qualité disponible taille mode responsable devoir devenir inclusive',
#  'utiliser matière naturel fabrication vêtement',
#  'réglementer terme durable éthique éviter',
#  'magasin couturier retoucheur client pouvoir retoucher rafistoler recoudre jeter',
#  'privilégier matière français fabrication français européen',
#  'arrêter fourrure plume oie cuir peau chat chien venir souffrance animal',
#  'produire',
#  'arrêter changement collection incessant vendre prix prix pousser consommation',
#  'créer vêtement qualité aller durer année non saison',
#  'fermer magasin vendre vêtement fabriquer loin salarié',
#  'utiliser matière naturel local gourmand eau chimique lin chanvre exemple',
#  'impact environnemental tangible consommateur nombre litre eau produire jean',
#  'freiner inciter',
#  'proposer atelier réparer vêtement proposer ré achat vêtement achat habit in',
#  'privilégier achat vêtement occasion',
#  '“ mode responsable tendance demain influencer consommateur positivement',
#  'limiter kilomètre distance entrer lieu vente lieu production',
#  'favoriser transparence consommateur capable retracer entièrement parcours produit mettre',
#  'marque enseigne proposer look basic recycler partie collection',
#  'encourager développement matière cuir raisin cuir pomme pouvoir local',
#  'arrêter surconsommation énormément nécessiter beaucoup ressource final gaspillage considérable',
#  'remplacer plastique emballage faire marque engager',
#  'informer jeune génération échelle mondial surconsommation mode jetable',
#  'utiliser vrai fourrure limiter maximum animal',
#  'utiliser savoir faire local petit entreprise atelier boutique collectif',
#  'soutenir boutique réemploi solidaire valoriser vêtement donner second vie lieu jeter',
#  'marque proposer service retouche remettre état boutique',
#  'acheter mieux qualité second main local',
#  'marque organiser propre filière « second main » ouvrir boutique live ligne',
#  'proposer produit qualité devoir vendre vrai prix production',
#  'donner maximum information compréhensible consommateur engager achat responsable',
#  'marque produire demande arrêter forme',
#  'inclure enfant travers jeu cadeau magasin sensibiliser parent protéger planète',
#  'accompagner financièrement entreprise français aider développer outil production',
#  'magasin vêtement occasion',
#  'sensibiliser consommateur filière',
#  'surtaxer lointain',
#  'actionnaire entreprise responsable fabriquer permettre création emploi territoire',
#  'définir fiche identité environnemental produit assurer',
#  'favoriser achat vêtement qualité fabriquer acheter mieux',
#  'taxer vêtement fabriquer matière naturel',
#  'arrêter grand opération commercial type solde black pousser surconsommation',
#  'exiger transparence marque mode terme production condition travailleur usine',
#  'mettre malus entreprise proposer collection an',
#  'privilégier in in loin in',
#  'faciliter identification vêtement durable fonction solidité durée vie estimer',
#  'interdire vêtement issu animal cuir fourrure écologique fabrication vente définitif',
#  'davantage règle norme label éviter',
#  'trouver solution surplus stock invendu lieu détruire donner association caritatif',
#  'remettre goût jour métier art type cordonnier chausseur tisseur filature couturier',
#  'proposer bon réduction client échange vieux sou vêtement vêtement recycler',
#  'recréer entreprise',
#  'partager coût produit entrer prix taxe écologique consommateur savoir poids acheter',
#  'privilégier matière naturel recyclée produire lin laine cellulose polyester recycler',
#  'arrêter exporter vêtement second main obliger consommer mieux recycler local',
#  'interdire éclairage vitrine nuit',
#  'développer permettre faire bilan consommation annuel calcul impact planète',
#  'valoriser produit uniquement second main agir domaine luxe',
#  'fabrication proposer produit prix',
#  'renforcer industrie filière textile local lin chanvre laine',
#  'créer produit responsable diminuer prix achat prix concurrentiel haut qualité',
#  'mettre place pratique achat responsable achat responsable aucun incidence condition travail',
#  'inciter marque produire maximum collection vêtement saison',
#  'utiliser matière fabrication vêtement',
#  'faire participer association choix consommateur office développement durable',
#  ...]

# %%
from collections import Counter

text = ' '.join(french_preprocess_list)
words = text.split()
word_counts = Counter(words)

top_10_words = word_counts.most_common(10)
for word, count in top_10_words:
    print(word, count)
# Out:
# vêtement 971
# produit 354
# matière 342
# marque 303
# proposer 270
# faire 240
# production 238
# arrêter 226
# produire 224
# recycler 207

# %%
len(words)
# Out:
# 21911

# %% [markdown]
# # Modèle Word2Vec + Kmeans

# %%
import gensim
from gensim.models import Word2Vec

tokenized_sentences = [sentence.split() for sentence in french_preprocess_list]

model = Word2Vec(tokenized_sentences, vector_size = 30, min_count=5,workers=5, window = 5, sg = 0)
model.train(tokenized_sentences, total_examples=len(tokenized_sentences), epochs=250)
# Out:
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (3558059, 5477750)

# %% [markdown]
# size : La dimension du vecteur créé, idéalement inférieur au nombre de mots du vocabulaire
#
# fenêtre : La distance maximale entre un mot cible et les mots autour du mot cible. La fenêtre par défaut est de 5.
#
# min_count : Le nombre minimum de mots à prendre en compte lors de l’apprentissage du modèle ; les mots dont l’occurrence est inférieure à ce nombre seront ignorés. La valeur par défaut de min_count est 5.
#
# Nombre de threads (workers) : Le paramètre workers contrôle le nombre de threads utilisés pour l'entraînement du modèle. Il est généralement recommandé de définir ce nombre en fonction du nombre de cœurs de processeur disponibles sur votre machine. Vous pouvez expérimenter avec différentes valeurs pour trouver un équilibre entre vitesse d'entraînement et utilisation des ressources. Par défaut il y en a 3

# %%
similar_words = model.wv.most_similar('cuir', topn=5)
for word, similarity in similar_words:
    print(word, similarity)
# Out:
# fourrure 0.6854709386825562
# souffrance 0.6539934873580933
# peau 0.5989286303520203
# animal 0.576585590839386
# biodégradable 0.5591128468513489

# %%
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt

def display_closestwords_tsnescatterplot_perso(model, word):
    arr = np.empty((0, model.vector_size), dtype='f')
    word_labels = [word]

    numb_sim_words = 10

    close_words = model.wv.most_similar(word)[:numb_sim_words]

    arr = np.append(arr, np.array([model.wv[word]]), axis=0)
    for wrd_score in close_words:
        wrd_vector = model.wv[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)

    tsne = TSNE(n_components=2, random_state=0, perplexity=5)  # Decreased perplexity value
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)

    x_coords = Y[:, 0]
    y_coords = Y[:, 1]

    color = ['red']
    for i in range(numb_sim_words):
        color.append('blue')

    plt.scatter(x_coords, y_coords, c=color)

    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(1, 5), textcoords='offset points')

    plt.xlim(min(x_coords) - 100, max(x_coords) + 100)
    plt.ylim(min(y_coords) - 100, max(y_coords) + 100)
    plt.show()

    print("Word most similar to: " + word)
    print([sim_word[0] for sim_word in close_words])

# %%
display_closestwords_tsnescatterplot_perso(model, tokenized_sentences[0][0])
# Out:
# Word most similar to: acheter
# ['consommer', 'habiller', 'pouvoir', 'faire', 'beaucoup', 'cher', 'achat', 'responsable', 'produire', 'prix']

# %%
#vectorisation des phrases via vecteur moyen

df['french_preprocess_list'] = french_preprocess_list

df.head()
# Out:
#    Unnamed: 0                                            content  \
# 0           3  Il faut ne faut pas acheter trop de vêtements ...
# 1           4  Il faut cesser de promouvoir des modes très ch...
# 2           5  il faut supprimer la méthode de sablage pour v...
# 3           6  Il faut encourager les marques à produire en E...
# 4           7  Il faut lourdement taxer le transport par port...
#
#                                                votes  author.age  \
# 0  [{'voteKey': 'agree', 'count': 29, 'qualificat...         NaN
# 1  [{'voteKey': 'agree', 'count': 269, 'qualifica...        29.0
# 2  [{'voteKey': 'agree', 'count': 35, 'qualificat...        50.0
# 3  [{'voteKey': 'agree', 'count': 57, 'qualificat...        29.0
# 4  [{'voteKey': 'agree', 'count': 98, 'qualificat...        50.0
#
#    author.postalCode  agree  agree_count_likeIt  agree_count_doable  \
# 0            35600.0     29                   8                   4
# 1                NaN    269                  63                  69
# 2            66000.0     35                   3                   9
# 3            31300.0     57                  12                  12
# 4                NaN     98                  20                  22
#
#    agree_count_platitude  disagree  disagree_noWay  disagree_impossible  \
# 0                      7         2               0                    0
# 1                     15        12               3                    3
# 2                      4         3               1                    1
# 3                      4         1               0                    0
# 4                      2         9               2                    2
#
#    disagree_platitude  neutral  neutral_doNotUnderstand  neutral_noOpinion  \
# 0                   1        7                        1                  2
# 1                   1       42                        1                  8
# 2                   0       19                        3                  6
# 3                   1        3                        0                  1
# 4                   1       21                        1                  4
#
#    neutral_count_doNotCare                             french_preprocess_list  \
# 0                        2     acheter trop vêtement utiliser mauvais qualité
# 1                        9  cesser promouvoir mode changeant privilégier v...
# 2                        2        supprimer méthode sablage vieillir vêtement
# 3                        0  encourager marque produire matière durable nat...
# 4                        0  lourdement taxer transport pollution fort trav...
#
#                                               tokens  \
# 0  [acheter, trop, vêtement, utiliser, mauvais, q...
# 1  [cesser, promouvoir, mode, changeant, privilég...
# 2  [supprimer, méthode, sablage, vieillir, vêtement]
# 3  [encourager, marque, produire, matière, durabl...
# 4  [lourdement, taxer, transport, pollution, fort...
#
#                                       average_vector
# 0  [0.5274835, 0.15270488, -1.0951359, 0.4241462,...
# 1  [-0.17426863, 0.37169424, -0.15784022, -0.5049...
# 2  [0.07956171, -0.7913923, -0.12539081, -0.05866...
# 3  [0.76261795, 1.0664318, -0.21503459, 0.5030638...
# 4  [0.04341202, 0.10361185, -1.6472591, 0.6076737...

# %%
def tokenize_text(text):
    tokens = nltk.word_tokenize(text)
    return tokens

df['tokens'] = df['french_preprocess_list'].apply(tokenize_text)

# %%
df.head()
# Out:
#    Unnamed: 0                                            content  \
# 0           3  Il faut ne faut pas acheter trop de vêtements ...
# 1           4  Il faut cesser de promouvoir des modes très ch...
# 2           5  il faut supprimer la méthode de sablage pour v...
# 3           6  Il faut encourager les marques à produire en E...
# 4           7  Il faut lourdement taxer le transport par port...
#
#                                                votes  author.age  \
# 0  [{'voteKey': 'agree', 'count': 29, 'qualificat...         NaN
# 1  [{'voteKey': 'agree', 'count': 269, 'qualifica...        29.0
# 2  [{'voteKey': 'agree', 'count': 35, 'qualificat...        50.0
# 3  [{'voteKey': 'agree', 'count': 57, 'qualificat...        29.0
# 4  [{'voteKey': 'agree', 'count': 98, 'qualificat...        50.0
#
#    author.postalCode  agree  agree_count_likeIt  agree_count_doable  \
# 0            35600.0     29                   8                   4
# 1                NaN    269                  63                  69
# 2            66000.0     35                   3                   9
# 3            31300.0     57                  12                  12
# 4                NaN     98                  20                  22
#
#    agree_count_platitude  disagree  disagree_noWay  disagree_impossible  \
# 0                      7         2               0                    0
# 1                     15        12               3                    3
# 2                      4         3               1                    1
# 3                      4         1               0                    0
# 4                      2         9               2                    2
#
#    disagree_platitude  neutral  neutral_doNotUnderstand  neutral_noOpinion  \
# 0                   1        7                        1                  2
# 1                   1       42                        1                  8
# 2                   0       19                        3                  6
# 3                   1        3                        0                  1
# 4                   1       21                        1                  4
#
#    neutral_count_doNotCare                             french_preprocess_list  \
# 0                        2     acheter trop vêtement utiliser mauvais qualité
# 1                        9  cesser promouvoir mode changeant privilégier v...
# 2                        2        supprimer méthode sablage vieillir vêtement
# 3                        0  encourager marque produire matière durable nat...
# 4                        0  lourdement taxer transport pollution fort trav...
#
#                                               tokens  \
# 0  [acheter, trop, vêtement, utiliser, mauvais, q...
# 1  [cesser, promouvoir, mode, changeant, privilég...
# 2  [supprimer, méthode, sablage, vieillir, vêtement]
# 3  [encourager, marque, produire, matière, durabl...
# 4  [lourdement, taxer, transport, pollution, fort...
#
#                                       average_vector
# 0  [0.5274835, 0.15270488, -1.0951359, 0.4241462,...
# 1  [-0.17426863, 0.37169424, -0.15784022, -0.5049...
# 2  [0.07956171, -0.7913923, -0.12539081, -0.05866...
# 3  [0.76261795, 1.0664318, -0.21503459, 0.5030638...
# 4  [0.04341202, 0.10361185, -1.6472591, 0.6076737...

# %%
df.to_csv('df_wtoken.csv')

# %%
import numpy as np

def calculate_average_vector(tokens):
    vectors = [model.wv[token] for token in tokens if token in model.wv]
    if len(vectors) > 0:
        average_vector = np.mean(vectors, axis=0)
        return average_vector
    else:
        return None

df['average_vector'] = df['tokens'].apply(calculate_average_vector)

# %%
df.head()
# Out:
#    Unnamed: 0                                            content  \
# 0           3  Il faut ne faut pas acheter trop de vêtements ...
# 1           4  Il faut cesser de promouvoir des modes très ch...
# 2           5  il faut supprimer la méthode de sablage pour v...
# 3           6  Il faut encourager les marques à produire en E...
# 4           7  Il faut lourdement taxer le transport par port...
#
#                                                votes  author.age  \
# 0  [{'voteKey': 'agree', 'count': 29, 'qualificat...         NaN
# 1  [{'voteKey': 'agree', 'count': 269, 'qualifica...        29.0
# 2  [{'voteKey': 'agree', 'count': 35, 'qualificat...        50.0
# 3  [{'voteKey': 'agree', 'count': 57, 'qualificat...        29.0
# 4  [{'voteKey': 'agree', 'count': 98, 'qualificat...        50.0
#
#    author.postalCode  agree  agree_count_likeIt  agree_count_doable  \
# 0            35600.0     29                   8                   4
# 1                NaN    269                  63                  69
# 2            66000.0     35                   3                   9
# 3            31300.0     57                  12                  12
# 4                NaN     98                  20                  22
#
#    agree_count_platitude  disagree  disagree_noWay  disagree_impossible  \
# 0                      7         2               0                    0
# 1                     15        12               3                    3
# 2                      4         3               1                    1
# 3                      4         1               0                    0
# 4                      2         9               2                    2
#
#    disagree_platitude  neutral  neutral_doNotUnderstand  neutral_noOpinion  \
# 0                   1        7                        1                  2
# 1                   1       42                        1                  8
# 2                   0       19                        3                  6
# 3                   1        3                        0                  1
# 4                   1       21                        1                  4
#
#    neutral_count_doNotCare                             french_preprocess_list  \
# 0                        2     acheter trop vêtement utiliser mauvais qualité
# 1                        9  cesser promouvoir mode changeant privilégier v...
# 2                        2        supprimer méthode sablage vieillir vêtement
# 3                        0  encourager marque produire matière durable nat...
# 4                        0  lourdement taxer transport pollution fort trav...
#
#                                               tokens  \
# 0  [acheter, trop, vêtement, utiliser, mauvais, q...
# 1  [cesser, promouvoir, mode, changeant, privilég...
# 2  [supprimer, méthode, sablage, vieillir, vêtement]
# 3  [encourager, marque, produire, matière, durabl...
# 4  [lourdement, taxer, transport, pollution, fort...
#
#                                       average_vector
# 0  [0.22392137, 0.5253627, -0.49509397, 0.5616202...
# 1  [0.118202634, 0.42558324, 0.2566399, -0.023860...
# 2  [0.8759346, -0.7096018, -0.18491675, -0.259130...
# 3  [0.669629, 0.9440671, -0.025996191, 0.44847795...
# 4  [-0.7447033, -0.310482, -1.5645254, 0.2570371,...

# %%
df.to_csv('df_wavgvector.csv')

# %%
import numpy as np

null_indices = np.where(df.average_vector.isnull())[0]

print("Indices des lignes avec des valeurs None :", null_indices)
# Out:
# Indices des lignes avec des valeurs None : [ 922 1482]

# %%
import pandas as pd

null_rows = df.iloc[null_indices]

null_rows.head()
# Out:
#       Unnamed: 0                                          content  \
# 922          925  Il faut transporter la marchandise par le train
# 1482        1485               Il faut ré-industrialisé en France
#
#                                                   votes  author.age  \
# 922   [{'voteKey': 'agree', 'count': 11, 'qualificat...        32.0
# 1482  [{'voteKey': 'agree', 'count': 180, 'qualifica...        52.0
#
#       author.postalCode  agree  agree_count_likeIt  agree_count_doable  \
# 922                 NaN     11                   3                   1
# 1482                NaN    180                  44                  35
#
#       agree_count_platitude  disagree  disagree_noWay  disagree_impossible  \
# 922                       0         1               0                    1
# 1482                      4         7               0                    2
#
#       disagree_platitude  neutral  neutral_doNotUnderstand  neutral_noOpinion  \
# 922                    0        5                        1                  2
# 1482                   0       25                        2                  7
#
#       neutral_count_doNotCare         french_preprocess_list  \
# 922                         0  transporter marchandise train
# 1482                        1
#
#                                  tokens average_vector
# 922   [transporter, marchandise, train]           None
# 1482                                 []           None

# %%
df_drop = df.drop('votes', axis = 1)

# %%
df_cleaned = df_drop.dropna(subset=['average_vector'])

# %%
df_cleaned
# Out:
#       Unnamed: 0                                            content  \
# 0              3  Il faut ne faut pas acheter trop de vêtements ...
# 1              4  Il faut cesser de promouvoir des modes très ch...
# 2              5  il faut supprimer la méthode de sablage pour v...
# 3              6  Il faut encourager les marques à produire en E...
# 4              7  Il faut lourdement taxer le transport par port...
# ...          ...                                                ...
# 2988        2991       Il faut favoriser le recyclage de vêtements
# 2989        2992  Il faut proposer des vêtements modulables,supe...
# 2990        2993  Il faut toujours afficher le lien de fabricati...
# 2991        2994  Il faut supprimer les produits chimiques dans ...
# 2992        2995  Il faut mentionner le nombre de personnes qui ...
#
#       author.age  author.postalCode  agree  agree_count_likeIt  \
# 0            NaN            35600.0     29                   8
# 1           29.0                NaN    269                  63
# 2           50.0            66000.0     35                   3
# 3           29.0            31300.0     57                  12
# 4           50.0                NaN     98                  20
# ...          ...                ...    ...                 ...
# 2988        32.0            91250.0     95                  14
# 2989        68.0                NaN     21                   1
# 2990         NaN                NaN    153                  26
# 2991        73.0            40380.0    141                  21
# 2992        47.0            75010.0     19                   3
#
#       agree_count_doable  agree_count_platitude  disagree  disagree_noWay  \
# 0                      4                      7         2               0
# 1                     69                     15        12               3
# 2                      9                      4         3               1
# 3                     12                      4         1               0
# 4                     22                      2         9               2
# ...                  ...                    ...       ...             ...
# 2988                  25                     11         1               0
# 2989                   9                      3         4               0
# 2990                  49                     10         9               0
# 2991                  38                     12         5               0
# 2992                   6                      0         3               0
#
#       disagree_impossible  disagree_platitude  neutral  \
# 0                       0                   1        7
# 1                       3                   1       42
# 2                       1                   0       19
# 3                       0                   1        3
# 4                       2                   1       21
# ...                   ...                 ...      ...
# 2988                    0                   1        4
# 2989                    0                   0       17
# 2990                    1                   4       25
# 2991                    3                   0       13
# 2992                    3                   0       13
#
#       neutral_doNotUnderstand  neutral_noOpinion  neutral_count_doNotCare  \
# 0                           1                  2                        2
# 1                           1                  8                        9
# 2                           3                  6                        2
# 3                           0                  1                        0
# 4                           1                  4                        0
# ...                       ...                ...                      ...
# 2988                        0                  0                        1
# 2989                        3                  3                        0
# 2990                        7                  2                        1
# 2991                        2                  3                        0
# 2992                        2                  2                        5
#
#                                  french_preprocess_list  \
# 0        acheter trop vêtement utiliser mauvais qualité
# 1     cesser promouvoir mode changeant privilégier v...
# 2           supprimer méthode sablage vieillir vêtement
# 3     encourager marque produire matière durable nat...
# 4     lourdement taxer transport pollution fort trav...
# ...                                                 ...
# 2988                       favoriser recyclage vêtement
# 2989  proposer vêtement superposable couvrir variati...
# 2990                afficher lien fabrication étiquette
# 2991                supprimer produit chimique vêtement
# 2992  mentionner nombre travailler produit in créer ...
#
#                                                  tokens  \
# 0     [acheter, trop, vêtement, utiliser, mauvais, q...
# 1     [cesser, promouvoir, mode, changeant, privilég...
# 2     [supprimer, méthode, sablage, vieillir, vêtement]
# 3     [encourager, marque, produire, matière, durabl...
# 4     [lourdement, taxer, transport, pollution, fort...
# ...                                                 ...
# 2988                   [favoriser, recyclage, vêtement]
# 2989  [proposer, vêtement, superposable, couvrir, va...
# 2990           [afficher, lien, fabrication, étiquette]
# 2991           [supprimer, produit, chimique, vêtement]
# 2992  [mentionner, nombre, travailler, produit, in, ...
#
#                                          average_vector
# 0     [0.22392137, 0.5253627, -0.49509397, 0.5616202...
# 1     [0.118202634, 0.42558324, 0.2566399, -0.023860...
# 2     [0.8759346, -0.7096018, -0.18491675, -0.259130...
# 3     [0.669629, 0.9440671, -0.025996191, 0.44847795...
# 4     [-0.7447033, -0.310482, -1.5645254, 0.2570371,...
# ...                                                 ...
# 2988  [0.18783148, 1.1627713, 0.9544845, 0.45751157,...
# 2989  [0.53577995, 0.87375534, 1.6247964, 0.15940875...
# 2990  [0.07421328, -1.2108475, 0.2703284, 0.08935746...
# 2991  [0.7265698, -0.96203226, -0.6348681, -0.129190...
# 2992  [0.33132508, -1.3176514, -0.029903242, -0.2726...
#
# [2991 rows x 19 columns]

# %%
from sklearn.manifold import TSNE
import numpy as np

vectors = np.array(df_cleaned['average_vector'].tolist())

tsne = TSNE(n_components=3, random_state=0, perplexity=5)
vectors_3d = tsne.fit_transform(vectors)

df_cleaned['average_vector_3d'] = vectors_3d.tolist()

print(df_cleaned)
# Out:
#       Unnamed: 0                                            content  \
# 0              3  Il faut ne faut pas acheter trop de vêtements ...
# 1              4  Il faut cesser de promouvoir des modes très ch...
# 2              5  il faut supprimer la méthode de sablage pour v...
# 3              6  Il faut encourager les marques à produire en E...
# 4              7  Il faut lourdement taxer le transport par port...
# ...          ...                                                ...
# 2988        2991       Il faut favoriser le recyclage de vêtements
# 2989        2992  Il faut proposer des vêtements modulables,supe...
# 2990        2993  Il faut toujours afficher le lien de fabricati...
# 2991        2994  Il faut supprimer les produits chimiques dans ...
# 2992        2995  Il faut mentionner le nombre de personnes qui ...
#
#       author.age  author.postalCode  agree  agree_count_likeIt  \
# 0            NaN            35600.0     29                   8
# 1           29.0                NaN    269                  63
# 2           50.0            66000.0     35                   3
# 3           29.0            31300.0     57                  12
# 4           50.0                NaN     98                  20
# ...          ...                ...    ...                 ...
# 2988        32.0            91250.0     95                  14
# 2989        68.0                NaN     21                   1
# 2990         NaN                NaN    153                  26
# 2991        73.0            40380.0    141                  21
# 2992        47.0            75010.0     19                   3
#
#       agree_count_doable  agree_count_platitude  disagree  disagree_noWay  \
# 0                      4                      7         2               0
# 1                     69                     15        12               3
# 2                      9                      4         3               1
# 3                     12                      4         1               0
# 4                     22                      2         9               2
# ...                  ...                    ...       ...             ...
# 2988                  25                     11         1               0
# 2989                   9                      3         4               0
# 2990                  49                     10         9               0
# 2991                  38                     12         5               0
# 2992                   6                      0         3               0
#
#       disagree_impossible  disagree_platitude  neutral  \
# 0                       0                   1        7
# 1                       3                   1       42
# 2                       1                   0       19
# 3                       0                   1        3
# 4                       2                   1       21
# ...                   ...                 ...      ...
# 2988                    0                   1        4
# 2989                    0                   0       17
# 2990                    1                   4       25
# 2991                    3                   0       13
# 2992                    3                   0       13
#
#       neutral_doNotUnderstand  neutral_noOpinion  neutral_count_doNotCare  \
# 0                           1                  2                        2
# 1                           1                  8                        9
# 2                           3                  6                        2
# 3                           0                  1                        0
# 4                           1                  4                        0
# ...                       ...                ...                      ...
# 2988                        0                  0                        1
# 2989                        3                  3                        0
# 2990                        7                  2                        1
# 2991                        2                  3                        0
# 2992                        2                  2                        5
#
#                                  french_preprocess_list  \
# 0        acheter trop vêtement utiliser mauvais qualité
# 1     cesser promouvoir mode changeant privilégier v...
# 2           supprimer méthode sablage vieillir vêtement
# 3     encourager marque produire matière durable nat...
# 4     lourdement taxer transport pollution fort trav...
# ...                                                 ...
# 2988                       favoriser recyclage vêtement
# 2989  proposer vêtement superposable couvrir variati...
# 2990                afficher lien fabrication étiquette
# 2991                supprimer produit chimique vêtement
# 2992  mentionner nombre travailler produit in créer ...
#
#                                                  tokens  \
# 0     [acheter, trop, vêtement, utiliser, mauvais, q...
# 1     [cesser, promouvoir, mode, changeant, privilég...
# 2     [supprimer, méthode, sablage, vieillir, vêtement]
# 3     [encourager, marque, produire, matière, durabl...
# 4     [lourdement, taxer, transport, pollution, fort...
# ...                                                 ...
# 2988                   [favoriser, recyclage, vêtement]
# 2989  [proposer, vêtement, superposable, couvrir, va...
# 2990           [afficher, lien, fabrication, étiquette]
# 2991           [supprimer, produit, chimique, vêtement]
# 2992  [mentionner, nombre, travailler, produit, in, ...
#
#                                          average_vector  \
# 0     [0.22392137, 0.5253627, -0.49509397, 0.5616202...
# 1     [0.118202634, 0.42558324, 0.2566399, -0.023860...
# 2     [0.8759346, -0.7096018, -0.18491675, -0.259130...
# 3     [0.669629, 0.9440671, -0.025996191, 0.44847795...
# 4     [-0.7447033, -0.310482, -1.5645254, 0.2570371,...
# ...                                                 ...
# 2988  [0.18783148, 1.1627713, 0.9544845, 0.45751157,...
# 2989  [0.53577995, 0.87375534, 1.6247964, 0.15940875...
# 2990  [0.07421328, -1.2108475, 0.2703284, 0.08935746...
# 2991  [0.7265698, -0.96203226, -0.6348681, -0.129190...
# 2992  [0.33132508, -1.3176514, -0.029903242, -0.2726...
#
#                                       average_vector_3d
# 0     [4.942734718322754, -1.903560757637024, 15.525...
# 1     [-3.1538593769073486, -7.409115314483643, 10.1...
# 2     [-7.488472938537598, -8.223966598510742, -3.31...
# 3     [-6.461948394775391, -8.257889747619629, 5.012...
# 4     [-13.360438346862793, -4.259009838104248, 1.02...
# ...                                                 ...
# 2988  [5.493187427520752, -8.70654296875, -14.926840...
# 2989  [12.537463188171387, -4.685950756072998, 22.68...
# 2990  [-23.56183624267578, 3.7373294830322266, -20.9...
# 2991  [-14.484990119934082, -7.478993892669678, -3.9...
# 2992  [-10.940142631530762, 14.757221221923828, 5.22...
#
# [2991 rows x 20 columns]
# <ipython-input-126-c97e67b60132>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pip --version sklearn
# Out:
# pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0                                            content  author.age  \
# 0           3  Il faut ne faut pas acheter trop de vêtements ...         NaN
# 1           4  Il faut cesser de promouvoir des modes très ch...        29.0
# 2           5  il faut supprimer la méthode de sablage pour v...        50.0
# 3           6  Il faut encourager les marques à produire en E...        29.0
# 4           7  Il faut lourdement taxer le transport par port...        50.0
#
#    author.postalCode  agree  agree_count_likeIt  agree_count_doable  \
# 0            35600.0     29                   8                   4
# 1                NaN    269                  63                  69
# 2            66000.0     35                   3                   9
# 3            31300.0     57                  12                  12
# 4                NaN     98                  20                  22
#
#    agree_count_platitude  disagree  disagree_noWay  ...  disagree_platitude  \
# 0                      7         2               0  ...                   1
# 1                     15        12               3  ...                   1
# 2                      4         3               1  ...                   0
# 3                      4         1               0  ...                   1
# 4                      2         9               2  ...                   1
#
#    neutral  neutral_doNotUnderstand  neutral_noOpinion  \
# 0        7                        1                  2
# 1       42                        1                  8
# 2       19                        3                  6
# 3        3                        0                  1
# 4       21                        1                  4
#
#    neutral_count_doNotCare                             french_preprocess_list  \
# 0                        2     acheter trop vêtement utiliser mauvais qualité
# 1                        9  cesser promouvoir mode changeant privilégier v...
# 2                        2        supprimer méthode sablage vieillir vêtement
# 3                        0  encourager marque produire matière durable nat...
# 4                        0  lourdement taxer transport pollution fort trav...
#
#                                               tokens  \
# 0  [acheter, trop, vêtement, utiliser, mauvais, q...
# 1  [cesser, promouvoir, mode, changeant, privilég...
# 2  [supprimer, méthode, sablage, vieillir, vêtement]
# 3  [encourager, marque, produire, matière, durabl...
# 4  [lourdement, taxer, transport, pollution, fort...
#
#                                       average_vector clusters_labels  \
# 0  [0.49006352, 0.055282395, 0.2588617, 0.1422179...               0
# 1  [-0.4067664, 0.07067796, 0.48135635, -0.682778...               0
# 2  [-0.21464069, -0.041760046, -0.08357673, 0.343...               4
# 3  [-0.17146662, -0.29801145, -0.4119433, -0.5976...               1
# 4  [-0.17321321, 0.2567789, -0.343469, -0.2427750...               3
#
#                                    average_vector_5d
# 0  [2.8524582386016846, 1.7246164083480835, 16.83...
# 1  [10.160107612609863, -9.109732627868652, 7.714...
# 2  [0.9847456216812134, 22.25995445251465, -3.001...
# 3  [-1.3354812860488892, 7.00425910949707, 9.1148...
# 4  [-22.165809631347656, -1.4668515920639038, -16...
#
# [5 rows x 21 columns]

# %%
from sklearn.cluster import KMeans

vectors = np.array(df_cleaned.average_vector_3d.tolist())

k = 4

kmeans = KMeans(n_clusters=k)
kmeans_fit = kmeans.fit(vectors)
#cluster_labels = kmeans.fit(vectors)

print(kmeans_fit.labels_)
# Out:
# [3 1 1 ... 0 1 0]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
df_cleaned['clusters_labels'] = kmeans_fit.labels_
# Out:
# <ipython-input-128-c4577e424e39>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0                                            content  author.age  \
# 0           3  Il faut ne faut pas acheter trop de vêtements ...         NaN
# 1           4  Il faut cesser de promouvoir des modes très ch...        29.0
# 2           5  il faut supprimer la méthode de sablage pour v...        50.0
# 3           6  Il faut encourager les marques à produire en E...        29.0
# 4           7  Il faut lourdement taxer le transport par port...        50.0
#
#    author.postalCode  agree  agree_count_likeIt  agree_count_doable  \
# 0            35600.0     29                   8                   4
# 1                NaN    269                  63                  69
# 2            66000.0     35                   3                   9
# 3            31300.0     57                  12                  12
# 4                NaN     98                  20                  22
#
#    agree_count_platitude  disagree  disagree_noWay  ...  disagree_platitude  \
# 0                      7         2               0  ...                   1
# 1                     15        12               3  ...                   1
# 2                      4         3               1  ...                   0
# 3                      4         1               0  ...                   1
# 4                      2         9               2  ...                   1
#
#    neutral  neutral_doNotUnderstand  neutral_noOpinion  \
# 0        7                        1                  2
# 1       42                        1                  8
# 2       19                        3                  6
# 3        3                        0                  1
# 4       21                        1                  4
#
#    neutral_count_doNotCare                             french_preprocess_list  \
# 0                        2     acheter trop vêtement utiliser mauvais qualité
# 1                        9  cesser promouvoir mode changeant privilégier v...
# 2                        2        supprimer méthode sablage vieillir vêtement
# 3                        0  encourager marque produire matière durable nat...
# 4                        0  lourdement taxer transport pollution fort trav...
#
#                                               tokens  \
# 0  [acheter, trop, vêtement, utiliser, mauvais, q...
# 1  [cesser, promouvoir, mode, changeant, privilég...
# 2  [supprimer, méthode, sablage, vieillir, vêtement]
# 3  [encourager, marque, produire, matière, durabl...
# 4  [lourdement, taxer, transport, pollution, fort...
#
#                                       average_vector  \
# 0  [0.47383806, 0.16286013, 0.053857803, -0.08074...
# 1  [-0.27501905, 0.021936607, 0.58968234, -0.7867...
# 2  [-0.4863768, 0.14843208, -0.013811859, 0.25220...
# 3  [-0.12070719, -0.34212235, -0.3507476, -0.4841...
# 4  [-0.22068171, 0.18881443, -0.4029948, -0.00888...
#
#                                    average_vector_3d clusters_labels
# 0  [3.7872562408447266, 3.3958189487457275, 14.19...               2
# 1  [9.133034706115723, -8.689759254455566, 4.9990...               2
# 2  [0.9293681383132935, 16.837282180786133, 3.959...               1
# 3  [-1.595320463180542, 9.348978996276855, 7.6568...               1
# 4  [-19.529321670532227, 0.4244564175605774, -14....               3
#
# [5 rows x 21 columns]

# %%
#Choix du nombre de clusters k (on fait varier k et on surveille l'évolution de l'inertie intra classes)
tab = []

vectors = np.array(df_cleaned.average_vector_3d.tolist())

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(vectors)
    tab.append(kmeans.inertia_)

plt.plot(range(1, 11), tab)
plt.title("Méthode Eblow / Méthode du coude")
plt.xlabel("Nombre de clusters")
plt.ylabel("Inertie de l'intra-classe")
plt.show()
#Le nombre optimal de clusters est le point représentant le coude. C'est le point à partir duquel la variance ne se réduit plus
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import plotly.graph_objects as go

fig = go.Figure()

for label in range(k):
    cluster_indices = np.where(cluster_labels == label)[0]
    cluster_data = cluster_vectors[cluster_indices]

    x_coords = cluster_data[:, 0]
    y_coords = cluster_data[:, 1]
    z_coords = cluster_data[:, 2]

    fig.add_trace(go.Scatter3d(
        x=x_coords,
        y=y_coords,
        z=z_coords,
        mode='markers',
        marker=dict(
            size=3,
            opacity=0.8
        ),
        name=f'Cluster {label}'
    ))

fig.update_layout(scene=dict(
    xaxis=dict(title='Dimension 1'),
    yaxis=dict(title='Dimension 2'),
    zaxis=dict(title='Dimension 3')
))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c84acabb-66ae-406c-8005-5f92322fc131" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c84acabb-66ae-406c-8005-5f92322fc131")) {                    Plotly.newPlot(                        "c84acabb-66ae-406c-8005-5f92322fc131",                        [{"marker":{"opacity":0.8,"size":3},"mode":"markers","name":"Cluster 0","x":[22.85727310180664,11.652868270874023,25.884031295776367,17.896059036254883,33.56977462768555,14.416509628295898,33.56991958618164,20.422014236450195,8.611572265625,17.50870132446289,6.435462951660156,21.423595428466797,14.100325584411621,18.780534744262695,22.407617568969727,15.100598335266113,13.649991989135742,11.288405418395996,11.210991859436035,18.624679565429688,20.04155158996582,22.92574691772461,21.364360809326172,12.379279136657715,21.73868179321289,13.424871444702148,6.069699764251709,14.450225830078125,20.284486770629883,10.931039810180664,23.75332260131836,19.803462982177734,22.86814308166504,24.308162689208984,16.198726654052734,17.864545822143555,12.486557006835938,29.141847610473633,15.909605026245117,17.20845603942871,17.38726043701172,18.477014541625977,3.246774911880493,16.575998306274414,20.405277252197266,12.36087703704834,7.444953918457031,29.662811279296875,29.580276489257812,21.931631088256836,22.845829010009766,19.976478576660156,25.509113311767578,28.37660789489746,17.55216407775879,7.706737518310547,13.714557647705078,1.890984296798706,11.602825164794922,14.3719482421875,13.37399673461914,17.76285171508789,11.468271255493164,22.155813217163086,14.219992637634277,11.275737762451172,19.904417037963867,5.553802967071533,8.020380020141602,29.43802833557129,12.776004791259766,18.02041244506836,10.462408065795898,18.759517669677734,13.098386764526367,23.79734992980957,23.357864379882812,17.460283279418945,8.823819160461426,17.98006248474121,9.819046020507812,23.25898551940918,6.054756164550781,23.735567092895508,25.200363159179688,22.205379486083984,18.65960121154785,18.448200225830078,25.292448043823242,25.276750564575195,20.073408126831055,12.710440635681152,3.8236117362976074,15.276248931884766,29.331186294555664,15.926767349243164,21.757568359375,26.666610717773438,12.219000816345215,19.649738311767578,8.70858383178711,17.799551010131836,23.77890396118164,20.224124908447266,19.725236892700195,12.938382148742676,13.629524230957031,8.284955978393555,19.911113739013672,24.063018798828125,23.172840118408203,11.901683807373047,26.37627410888672,7.825438022613525,18.74818229675293,25.29800033569336,23.636093139648438,6.949440002441406,13.1692476272583,22.147687911987305,13.946104049682617,9.872806549072266,15.234932899475098,22.860626220703125,24.34830093383789,12.945601463317871,2.103817939758301,8.465641021728516,20.592029571533203,17.81138801574707,15.795071601867676,30.017518997192383,12.522282600402832,15.195834159851074,13.526458740234375,20.19952392578125,8.415246963500977,18.946577072143555,17.49213981628418,24.159183502197266,13.827404022216797,9.241293907165527,16.913482666015625,12.589166641235352,17.02197265625,13.970000267028809,26.971641540527344,13.399683952331543,13.05372142791748,20.457361221313477,4.3946051597595215,12.016155242919922,26.084733963012695,27.187761306762695,13.68980884552002,28.47968101501465,21.99786949157715,20.67291831970215,17.670021057128906,20.486499786376953,16.998279571533203,17.916847229003906,18.352617263793945,11.746455192565918,2.1981472969055176,17.77988052368164,19.550092697143555,10.861614227294922,14.042560577392578,14.718009948730469,19.613513946533203,18.619216918945312,23.93463897705078,26.57200813293457,6.801784992218018,23.46123695373535,18.001964569091797,11.3471097946167,19.49667739868164,26.046783447265625,14.992382049560547,19.6732501983642 ...

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0                                            content  author.age  \
# 0           3  Il faut ne faut pas acheter trop de vêtements ...         NaN
# 1           4  Il faut cesser de promouvoir des modes très ch...        29.0
# 2           5  il faut supprimer la méthode de sablage pour v...        50.0
# 3           6  Il faut encourager les marques à produire en E...        29.0
# 4           7  Il faut lourdement taxer le transport par port...        50.0
#
#    author.postalCode  agree  agree_count_likeIt  agree_count_doable  \
# 0            35600.0     29                   8                   4
# 1                NaN    269                  63                  69
# 2            66000.0     35                   3                   9
# 3            31300.0     57                  12                  12
# 4                NaN     98                  20                  22
#
#    agree_count_platitude  disagree  disagree_noWay  ...  disagree_platitude  \
# 0                      7         2               0  ...                   1
# 1                     15        12               3  ...                   1
# 2                      4         3               1  ...                   0
# 3                      4         1               0  ...                   1
# 4                      2         9               2  ...                   1
#
#    neutral  neutral_doNotUnderstand  neutral_noOpinion  \
# 0        7                        1                  2
# 1       42                        1                  8
# 2       19                        3                  6
# 3        3                        0                  1
# 4       21                        1                  4
#
#    neutral_count_doNotCare                             french_preprocess_list  \
# 0                        2     acheter trop vêtement utiliser mauvais qualité
# 1                        9  cesser promouvoir mode changeant privilégier v...
# 2                        2        supprimer méthode sablage vieillir vêtement
# 3                        0  encourager marque produire matière durable nat...
# 4                        0  lourdement taxer transport pollution fort trav...
#
#                                               tokens  \
# 0  [acheter, trop, vêtement, utiliser, mauvais, q...
# 1  [cesser, promouvoir, mode, changeant, privilég...
# 2  [supprimer, méthode, sablage, vieillir, vêtement]
# 3  [encourager, marque, produire, matière, durabl...
# 4  [lourdement, taxer, transport, pollution, fort...
#
#                                       average_vector  \
# 0  [0.47383806, 0.16286013, 0.053857803, -0.08074...
# 1  [-0.27501905, 0.021936607, 0.58968234, -0.7867...
# 2  [-0.4863768, 0.14843208, -0.013811859, 0.25220...
# 3  [-0.12070719, -0.34212235, -0.3507476, -0.4841...
# 4  [-0.22068171, 0.18881443, -0.4029948, -0.00888...
#
#                                    average_vector_3d clusters_labels
# 0  [3.7872562408447266, 3.3958189487457275, 14.19...               2
# 1  [9.133034706115723, -8.689759254455566, 4.9990...               2
# 2  [0.9293681383132935, 16.837282180786133, 3.959...               1
# 3  [-1.595320463180542, 9.348978996276855, 7.6568...               1
# 4  [-19.529321670532227, 0.4244564175605774, -14....               3
#
# [5 rows x 21 columns]

# %%
from collections import Counter

cluster_words = {}

for label in range(k):
    cluster_indices = np.where(df_cleaned['clusters_labels'] == label)[0]
    cluster_sentences = df_cleaned.iloc[cluster_indices]['french_preprocess_list'].tolist()

    word_counter = Counter()
    for sentence in cluster_sentences:
        words = sentence.split()
        word_counter.update(words)

    cluster_words[label] = [word for word, count in word_counter.most_common(30)]

for label, words in cluster_words.items():
    print(f"Cluster {label}:")
    print(words)
    print()
# Out:
# Cluster 0:
# ['vêtement', 'produit', 'production', 'marque', 'fabrication', 'impact', 'consommateur', 'matière', 'entreprise', 'étiquette', 'environnemental', 'mode', 'condition', 'travail', 'textile', 'mettre', 'transparence', 'responsable', 'écologique', 'pays', 'social', 'éthique', 'informer', 'créer', 'fabriquer', 'carbone', 'environnement', 'label', 'sensibiliser', 'lieu']
#
# Cluster 1:
# ['matière', 'vêtement', 'utiliser', 'naturel', 'plastique', 'produit', 'recycler', 'fabriquer', 'lin', 'production', 'coton', 'arrêter', 'produire', 'local', 'privilégier', 'textile', 'fibre', 'limiter', 'emballage', 'animal', 'favoriser', 'tissu', 'français', 'fabrication', 'chanvre', 'proposer', 'non', 'synthétique', 'cuir', 'durable']
#
# Cluster 2:
# ['vêtement', 'proposer', 'second', 'main', 'marque', 'recycler', 'magasin', 'recyclage', 'faire', 'achat', 'donner', 'pouvoir', 'occasion', 'bon', 'développer', 'client', 'vie', 'ancien', 'invendu', 'mettre', 'enseigne', 'produit', 'boutique', 'vente', 'créer', 'usager', 'acheter', 'favoriser', 'collecte', 'arrêter']
#
# Cluster 3:
# ['vêtement', 'collection', 'produire', 'arrêter', 'qualité', 'faire', 'produit', 'prix', 'acheter', 'proposer', 'marque', 'mode', 'fabriquer', 'savoir', 'production', 'réduire', 'mieux', 'consommer', 'nombre', 'saison', 'quantité', 'éviter', 'année', 'local', 'limiter', 'achat', 'an', 'besoin', 'français', 'durable']

# %%
cluster_representative_sentences = {}

for label in range(k):
    cluster_indices = np.where(df_cleaned['clusters_labels'] == label)[0]
    cluster_sentences = df_cleaned.iloc[cluster_indices]['french_preprocess_list'].tolist()

    center_distance = kmeans_fit.transform(vectors[cluster_indices])[:, label]
    representative_sentence_index = np.argmin(center_distance)

    representative_sentence = cluster_sentences[representative_sentence_index]

    cluster_representative_sentences[label] = representative_sentence

for label, sentence in cluster_representative_sentences.items():
    print(f"Cluster {label}: {sentence}")
# Out:
# Cluster 0: prix étiquette justifier éthique marque réel engagement non communication opportuniste
# Cluster 1: surtaxer produit polluant matière plastique marque surproduction invendu stock déchet
# Cluster 2: faciliter revente vêtement boutique officiel revente
# Cluster 3: acheter acheter vêtement qualité devoir

# %%
# Créer un dictionnaire pour stocker les phrases les plus proches du centre de chaque cluster
cluster_closest_sentences = {}

# Parcourir chaque cluster
for label in range(k):
    # Filtrer les phrases appartenant au cluster actuel
    cluster_indices = np.where(df_cleaned['clusters_labels'] == label)[0]
    cluster_sentences = df_cleaned.iloc[cluster_indices]['french_preprocess_list'].tolist()

    # Calculer les distances des vecteurs au centre du cluster
    distances = kmeans_fit.transform(vectors[cluster_indices])

    # Récupérer les indices des 10 phrases les plus proches
    closest_sentence_indices = np.argsort(distances[:, label])[:10]

    # Récupérer les phrases les plus proches
    closest_sentences = [cluster_sentences[i] for i in closest_sentence_indices]

    cluster_closest_sentences[label] = closest_sentences

for label, sentences in cluster_closest_sentences.items():
    print(f"Cluster {label}:")
    for sentence in sentences:
        print(sentence)
    print()
# Out:
# Cluster 0:
# prix étiquette justifier éthique marque réel engagement non communication opportuniste
# créer notation public noter marque respect engagement
# engagement résultat direction faveur handicaper
# tourner marque éthique fonctionner principe profit dominer
# établir relation constructif éthique fournisseur
# obliger marque fabricant engager mode responsable travail décent matière éthique
# marque engager produire vêtement éthique procédé fabrication
# annuaire ligne recenser marque éthique action écologique marque existant
# visible engagement marque responsable éthique faciliter recherche acheteur sensibiliser
# proposer marque engagement éthique prochain année
#
# Cluster 1:
# surtaxer produit polluant matière plastique marque surproduction invendu stock déchet
# vêtement matière naturel favoriser transpiration polluant lavage
# privilégier maximum matière naturel polluant confection vêtement
# éviter matière base pétrole traitement chimique matière synthétique
# privilégier matière naturel éviter matière synthétique
# privilégier bambou produit naturel arrêter matière synthétique
# interdire matière non écologique autoriser coton lin plante veiller faire surproduction
# proposer matière naturel
# produit chimie base pétrole
# arrêter produire tissu base procédé chimique
#
# Cluster 2:
# faciliter revente vêtement boutique officiel revente
# proposer boutique revente vêtement marque pouvoir venir essayer taille
# faciliter revente recyclage vêtement magasin ex boutique payer récupérer vêtement
# enlever gratuit favoriser essayage boutique proposer vêtement morphologie
# commune créer aide installer boutique vêtement alternatif centre ville
# ouvrir boutique faire troc vêtement condition client jeter payer
# aider modeste acquérir vêtement faire exemple offrir paiement fois boutique
# faire proposer marque proposer remettre vente vêtement occasion marque
# faciliter échange vêtement entrer particulier
# organiser troc entrer client
#
# Cluster 3:
# acheter acheter vêtement qualité devoir
# pouvoir acheter habit qualité démoder devoir temps
# acheter produit meilleur qualité temps devoir accessible cher
# produire produit qualité cher devoir
# faire meilleur qualité quitte payer cher vêtement utilisable année
# prêt acheter meilleur qualité quitte payer cher valoir euro normal
# arrêter produire mode jetable gamme déchirer trouer mois
# arrêter produire produit gamme déchirer découdre peine porter pousser consommation
# arrêter consommation masse besoin tonne vêtement gamme vêtement jetable revenir qualité
# arrêter produire vêtement jetable mauvais qualité associer surproduction

# %%
best_dbscan = DBSCAN(eps = 8, min_samples= 100)
best_dbscan.fit(vectors)
cluster_labels_dbscan = best_dbscan.labels_

# %%
best_dbscan = DBSCAN(eps = 5.6, min_samples= 50)
best_dbscan.fit(vectors)
cluster_labels_dbscan = best_dbscan.labels_
unique_labels = np.unique(cluster_labels_dbscan)

# %%
import matplotlib.pyplot as plt

unique_labels = np.unique(cluster_labels_dbscan)
plt.figure(figsize=(10,8))
for label in unique_labels:
    if label == -1:
        cluster_points = vectors[cluster_labels_dbscan == label]
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], c='gray', label='Noise')
    else:
        cluster_points = vectors[cluster_labels_dbscan == label]
        plt.scatter(cluster_points[:, 0], cluster_points[:, 1], label=f'Cluster {label}')

plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend()
plt.show()

# %%
cluster_words = {}
cluster_sentences = {}

for label in unique_labels:
    if label == -1:
        continue

    cluster_indices = np.where(cluster_labels_dbscan == label)[0]
    cluster_texts = df_cleaned.iloc[cluster_indices]['french_preprocess_list'].tolist()

    word_counter = Counter()
    for text in cluster_texts:
        words = text.split()
        word_counter.update(words)

    # Extraire les 30 mots les plus fréquents du cluster
    cluster_words[label] = [word for word, count in word_counter.most_common(30)]

    # Stocker les phrases représentatives du cluster
    cluster_sentences[label] = cluster_texts[:20]

# %%
for label, words in cluster_words.items():
    print(f"Cluster {label}:")
    print(words)
    print()
# Out:
# Cluster 0:
# ['vêtement', 'second', 'main', 'proposer', 'marque', 'magasin', 'occasion', 'recyclage', 'vente', 'développer', 'boutique', 'achat', 'revente', 'vie', 'mettre', 'neuf', 'enseigne', 'collecte', 'faire', 'favoriser', 'produit', 'location', 'recycler', 'place', 'acheter', 'réseau', 'faciliter', 'mode', 'point', 'échange']
#
# Cluster 1:
# ['matière', 'naturel', 'utiliser', 'vêtement', 'recycler', 'chimique', 'produit', 'coton', 'synthétique', 'polluant', 'plastique', 'tissu', 'fabriquer', 'privilégier', 'produire', 'fibre', 'issu', 'lin', 'teinture', 'limiter', 'non', 'utilisation', 'végétal', 'éviter', 'matériau', 'arrêter', 'favoriser', 'interdire', 'fabrication', 'textile']
#
# Cluster 2:
# ['vêtement', 'recycler', 'magasin', 'proposer', 'marque', 'bon', 'ancien', 'usager', 'client', 'recyclage', 'ramener', 'reprendre', 'pouvoir', 'état', 'main', 'réduction', 'vieux', 'achat', 'échange', 'second', 'rapporter', 'donner', 'revendre', 'porter', 'user', 'enseigne', 'inciter', 'récupération', 'circuit', 'article']
#
# Cluster 3:
# ['vêtement', 'produire', 'arrêter', 'marque', 'matière', 'faire', 'durable', 'fabriquer', 'étiquette', 'collection', 'réduire', 'production', '«', '»', 'localement', 'recycler', 'mode', 'industrie', 'produit', 'mettre', 'qualité', 'transport', 'textile', 'non', 'proposer', 'cher', 'monde', 'naturel', 'coût', 'éviter']

# %%
for label, sentences in cluster_sentences.items():
    print(f"Cluster {label}:")
    for i, sentence in enumerate(sentences, 1):
        print(f"Phrase {i}: {sentence}")
    print()
# Out:
# Cluster 0:
# Phrase 1: développer second sein magasin vêtement neuf
# Phrase 2: enseigne proposer service location vêtement bébé
# Phrase 3: développer second main mode recyclée encourageant collecte vêtement porter
# Phrase 4: recycler vêtement faire collecte textile proposer avantage client forme point cagnotte
# Phrase 5: réussir faire échange entrer consommateur forcément côté vente nouveauté
# Phrase 6: sensibiliser marché second main forcément sale synonyme pauvreté jugement valeur
# Phrase 7: créer espace revalorisation vêtement occasion grand enseigne atelier couture collecte revente
# Phrase 8: enseigne proposer seconde main marque
# Phrase 9: inclure promouvoir politique second main offre commercial
# Phrase 10: encourager braderie vente article occasion
# Phrase 11: favoriser usage proposer location second main vide
# Phrase 12: développer concept magasin second main marque vêtement luxe
# Phrase 13: favoriser achat second main
# Phrase 14: magasine démocratisent second main mettre marque éthique lux inconscient
# Phrase 15: prévoir rayon vente vêtement main magasin prêt porter
# Phrase 16: permettre particulier donner vêtement recyclage magasin
# Phrase 17: organiser troc entrer client
# Phrase 18: boutique travailler réseau stock collectif proposer client production raisonner
# Phrase 19: proposer second utilisation vêtement transformation facile second usage
# Phrase 20: mettre place boutique rayon vêtement porter occasion tarif réduit
#
# Cluster 1:
# Phrase 1: supprimer méthode sablage vieillir vêtement
# Phrase 2: changer procédé teinture teinture polluant
# Phrase 3: supprimer détergent chimique toxique
# Phrase 4: produire fibre tisser confectionner vêtement défaut
# Phrase 5: grand entreprise impliquer projet ex plastique polluant mer
# Phrase 6: interdire matière polluant sequin paillette
# Phrase 7: éviter cuir végétal majoritairement composer plastique
# Phrase 8: utiliser produit naturel matière teinture limiter allergie peau
# Phrase 9: privilégier matière issu culture biologique nécessiter pesticide eau
# Phrase 10: penser bonne matière naturel recycler
# Phrase 11: utiliser matière naturel non polluant coton bambou innovant déchet raisin ananas bière
# Phrase 12: privilégier matière naturel synthétique préférer polyester recycler
# Phrase 13: utilisation paillette matériau pouvoir détacher lavage rejoindre milieu naturel
# Phrase 14: interdire produit chimique irritant vêtement
# Phrase 15: moderniser autonome approvisionnement
# Phrase 16: revenir matière naturel type coton lin laine limiter matière synthétique
# Phrase 17: informer citoyen impact tissu synthétique pollution déverser océan
# Phrase 18: pédagogie matière fibre clarifier composition vêtement
# Phrase 19: intégrer matière biologique approvisionnement local programme pédagogique école mode
# Phrase 20: proposer matière naturel
#
# Cluster 2:
# Phrase 1: magasin récupérer vieux chaussure recycler
# Phrase 2: obliger marque recycler ancien vêtement principe pollueur payeur
# Phrase 3: faciliter recyclage vêtement proposer ramener vêtement magasin gratuitement année
# Phrase 4: marque racheter sou forme bon achat vêtement bon état partie magasin
# Phrase 5: proposer recycler tissu vêtement trop usager parallèle proposer vêtement main
# Phrase 6: recycler vêtement non utiliser magasin devoir proposer reprise vêtement user échange réduction
# Phrase 7: marque engager récupérer ancien produit recycler fibre donner association
# Phrase 8: proposer client sorte consigne vêtement plaire marque engager recycler bon donner
# Phrase 9: remettre vêtement circuit offrir second vie
# Phrase 10: proposer uniquement cintre bois proposer vente client
# Phrase 11: marque reprendre vêtement euro symbolique recycler revendre second main
# Phrase 12: enseigne racheter reprendre produit revendre occasion
# Phrase 13: remettre circuit vêtement second main bon état contre réduction utiliser endommagé faire
# Phrase 14: reprendre chaussure usager recycler
# Phrase 15: rayon occasion magasin vêtement reprendre ancien modèle
# Phrase 16: maison vieux article client récupérer matière client prix
# Phrase 17: donner possibilité client ramener vêtement porter boutique faciliter recyclage
# Phrase 18: créer échange recyclage ancien vêtement redistribution vêtement jeter
# Phrase 19: magasin vêtement reprendre ancien article client revendre magasin corner second main
# Phrase 20: recycler vieux vieux maillot donner vie
#
# Cluster 3:
# Phrase 1: cesser promouvoir mode changeant privilégier vêtement durable solide bon qualité
# Phrase 2: encourager marque produire matière durable naturel recyclée
# Phrase 3: arrêter produire vêtement coût jeter lavage
# Phrase 4: développer matière marque vendre grand quantité défi production
# Phrase 5: éviter faire perdre emploi créer transport
# Phrase 6: ralentir « saison » collection désigner vêtement « out » mois tard
# Phrase 7: réduire déchet produire favoriser recyclage marché occasion industrie mode devoir réinventer
# Phrase 8: réutiliser produit vêtement tissu mercerie produire fabriquer localement
# Phrase 9: fabriquer localement
# Phrase 10: autoriser vente vêtement cas connaissance fournisseur marque final
# Phrase 11: arrêter fabriquer vêtement bout planète industrie textile
# Phrase 12: privilégier vente magasin non internet aller créer emploi
# Phrase 13: responsabiliser consommateur non changer jour industrie textile énormément
# Phrase 14: arrêter faire appel intermédiaire exploiter population produire scandale
# Phrase 15: détaxer vêtement produire localement
# Phrase 16: favoriser matière issu recyclage vrai solution jour
# Phrase 17: arrêter multiplication étiquette vêtement marque remplacer code
# Phrase 18: arrêter coudre étiquette vêtement place imprimer papier recycler tissu
# Phrase 19: arrêter green promouvoir matière
# Phrase 20: mode changer prendre compte ressource nécessaire fabriquer vêtement
